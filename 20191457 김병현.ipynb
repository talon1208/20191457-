# %% [markdown]
# # 실습: Darknet을 이용하여 커스텀 YOLOv3를 빌드하기
#
# This tutorial is a copy of the one made by 'The AI Guy'.
# The link to the original tutorial and the author is : [The AI Guy](https://www.youtube.com/channel/UCrydcKaojc44XnuXrfhlV8Q)
#
# 폴더등과 관련된 몇 가지 오류를 수정하고 한글화함

# %% [markdown]
# # 1. Darknet를 clone하기
#
# 다음 셀들은
# <ol>
# <li> AlexeyAB repository에서 darknet을 clone하고 </li>
# <li> darknet에서 OPENCV and GPU의 사용을 enable하기 위해 make파일을 수정하고 </li>
# <li> darknet을 빌드함 </li>
# </ol>

# %%
# darknet repository에서 clone하기
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15851, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 15851 (delta 5), reused 13 (delta 4), pack-reused 15833
# Receiving objects: 100% (15851/15851), 14.42 MiB | 18.17 MiB/s, done.
# Resolving deltas: 100% (10671/10671), done.

# %%
#GPU와 OPENCV의 사용이 가능하도록  makefile을 수정하기
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# Out:
# /content/darknet

# %%
# CUDA버전 확인하기
# !/usr/local/cuda/bin/nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2023 NVIDIA Corporation
# Built on Tue_Aug_15_22:02:13_PDT_2023
# Cuda compilation tools, release 12.2, V12.2.140
# Build cuda_12.2.r12.2/compiler.33191640_0

# %%
# make를 이용하여 darknet를 build
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# mkdir -p results
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:945:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#   945 |                 float rgb[3];
#       |                       ^~~
# ./src/image_opencv.cpp: In function ‘void cv_draw_object(image, float*, int, int, int*, float*, int*, int, char**)’:
# ./src/image_opencv.cpp:1443:14: warning: unused variable ‘buff’ [-Wunused-variable]
#  1443 |         char buff[100];
#       |              ^~~~
# ./src/image_opencv.cpp:1419:9: warning: unused variable ‘it_tb_res’ [-Wunused-variable]
#  1419 |     int it_tb_res = cv::createTrackbar(it_trackbar_name, window_name, &it_trackbar_value, 1000);
#       |         ^~~~~~~~~
# ./src/image_opencv.cpp:1423:9: warning: unused variable ‘lr_tb_res’ [-Wunused-variable]
#  1423 |     int lr_tb_res = cv::createTrackbar(lr_trackbar_name, window_name, &lr_trackbar_value, 20);
#       |         ^~~~~~~~~
# ./src/image_opencv.cpp:1427:9: warning: unused variable ‘cl_tb_res’ [-Wunused-variable]
#  1427 |     int cl_tb_res = cv::createTrackbar(cl_trackbar_name, window_name, &cl_trackbar_value, classes-1);
#       |         ^~~~~~~~~
# ./src/image_opencv.cpp:1430:9: warning: unused variable ‘bo_tb_res’ [-Wunused-variable]
#  1430 |     int bo_tb_res = cv::createTrackbar(bo_trackbar_name, window_name, boxonly, 1);
#       |         ^~~~~~~~~
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/http_stream.cpp -o obj/http_stream.o
# ./src/http_stream.cpp: In member function ‘bool JSON_sender::write(const char*)’:
# ./src/http_stream.cpp:253:21: warning: unused variable ‘n’ [-Wunused-variable]
#   253 |                 int n = _write(client, outputbuf, outlen);
#       |                     ^
# ./src/http_stream.cpp: In function ‘void set_track_id(detection*, int, float, float, float, int, int, int)’:
# ./src/http_stream.cpp:866:27: warning: comparison of integer expressions of different signedness: ‘int’ and ‘std::vector<detection_t>::size_type’ {aka ‘long unsigned int’} [-Wsign-compare]
#   866 |         for (int i = 0; i < v.size(); ++i) {
#       |                         ~~^~~~~~~~~~
# ./src/http_stream.cpp:874:33: warning: comparison of integer expressions of different signedness: ‘int’ and ‘std::vector<detection_t>::size_type’ {aka ‘long unsigned int’} [-Wsign-compare]
#   874 |     for (int old_id = 0; old_id < old_dets.size(); ++old_id) {
#       |                          ~~~~~~~^~~~~~~~~~~~~~~~~
# ./src/http_stream.cpp:893:31: warning: comparison of integer expressions of different signedness: ‘int’ and ‘std::vector<detection_t>::size_type’ {aka ‘long unsigned int’} [-Wsign-compare]
#   893 |     for (int index = 0; index < new_dets_num*old_dets.size(); ++index) {
#       |                         ~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ./src/http_stream.cpp:929:28: warning: comparison of integer expressions of different signedness: ‘std::deque<std::vector<detection_t> >::size_type’ {aka ‘long unsigned int’} and ‘int’ [-Wsign-compare]
#   929 |     if (old_dets_dq.size() > deque_size) old_dets_dq.pop_front();
#       |         ~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/gemm.c -o obj/gemm.o
# ./src/gemm.c: In function ‘convolution_2d’:
# ./src/gemm.c:2042:15: warning: unused variable ‘out_w’ [-Wunused-variable]
#  2042 |     const int out_w = (w + 2 * pad - ksize) / stride + 1;    // output_width=input_width for stride=1 and pad=1
#       |               ^~~~~
# ./src/gemm.c:2041:15: warning: unused variable ‘out_h’ [-Wunused-variable]
#  2041 |     const int out_h = (h + 2 * pad - ksize) / stride + 1;    // output_height=input_height for stride=1 and pad=1
#       |               ^~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/utils.c -o obj/utils.o
# ./src/utils.c: In function ‘custom_hash’:
# ./src/utils.c:1093:12: warning: suggest parentheses around assignment used as truth value [-Wparentheses]
#  1093 |     while (c = *str++)
#       |            ^
# In file included from /usr/include/string.h:535,
#                  from include/darknet.h:14,
#                  from ./src/utils.h:3,
#                  from ./src/utils.c:4:
# In function ‘strncpy’,
#     inlined from ‘copy_string’ at ./src/utils.c:563:5:
# /usr/include/x86_64-linux-gnu/bits/string_fortified.h:95:10: warning: ‘__builtin_strncpy’ specified bound depends on the length of the source argument [-Wstringop-truncation]
#    95 |   return __builtin___strncpy_chk (__dest, __src, __len,
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    96 |                                   __glibc_objsize (__dest));
#       |                                   ~~~~~~~~~~~~~~~~~~~~~~~~~
# ./src/utils.c: In function ‘copy_string’:
# ./src/utils.c:563:22: note: length computed here
#   563 |     strncpy(copy, s, strlen(s)+1);
#       |                      ^~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/dark_cuda.c -o obj/dark_cuda.o
# ./src/dark_cuda.c: In function ‘cudnn_check_error_extended’:
# ./src/dark_cuda.c:218:20: warning: comparison between ‘cudaError_t’ {aka ‘enum cudaError’} and ‘enum <anonymous>’ [-Wenum-compare]
#   218 |         if (status != CUDNN_STATUS_SUCCESS)
#       |                    ^~
# ./src/dark_cuda.c: In function ‘cublas_check_error_extended’:
# ./src/dark_cuda.c:252:18: warning: comparison between ‘cudaError_t’ {aka ‘enum cudaError’} and ‘enum cudaError_enum’ [-Wenum-compare]
#   252 |       if (status != CUDA_SUCCESS)
#       |                  ^~
# At top level:
# ./src/dark_cuda.c:275:23: warning: ‘switchBlasHandle’ defined but not used [-Wunused-variable]
#   275 | static cublasHandle_t switchBlasHandle[16];
#       |                       ^~~~~~~~~~~~~~~~
# ./src/dark_cuda.c:274:12: warning: ‘switchBlasInit’ defined but not used [-Wunused-variable]
#   274 | static int switchBlasInit[16] = { 0 };
#       |            ^~~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/convolutional_layer.c -o obj/convolutional_layer.o
# ./src/convolutional_layer.c: In function ‘forward_convolutional_layer’:
# ./src/convolutional_layer.c:1335:32: warning: unused variable ‘t_intput_size’ [-Wunused-variable]
#  1335 |                         size_t t_intput_size = binary_transpose_align_input(k, n, state.workspace, &l.t_bit_input, ldb_align, l.bit_align);
#       |                                ^~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/list.c -o obj/list.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image.c -o obj/image.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/activations.c -o obj/activations.o
# ./src/activations.c: In function ‘activate’:
# ./src/activations.c:79:5: warning: enumeration value ‘RELU6’ not handled in switch [-Wswitch]
#    79 |     switch(a){
#       |     ^~~~~~
# ./src/activations.c:79:5: warning: enumeration value ‘SWISH’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘MISH’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘HARD_MISH’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘NORM_CHAN’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘NORM_CHAN_SOFTMAX’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘NORM_CHAN_SOFTMAX_MAXVAL’ not handled in switch [-Wswitch]
# ./src/activations.c: In function ‘gradient’:
# ./src/activations.c:310:5: warning: enumeration value ‘SWISH’ not handled in switch [-Wswitch]
#   310 |     switch(a){
#       |     ^~~~~~
# ./src/activations.c:310:5: warning: enumeration value ‘MISH’ not handled in switch [-Wswitch]
# ./src/activations.c:310:5: warning: enumeration value ‘HARD_MISH’ not handled in switch [-Wswitch]
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/im2col.c -o obj/im2col.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/col2im.c -o obj/col2im.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/blas.c -o obj/blas.o
# ./src/blas.c: In function ‘backward_shortcut_multilayer_cpu’:
# ./src/blas.c:207:21: warning: unused variable ‘out_index’ [-Wunused-variable]
#   207 |                 int out_index = id;
#       |                     ^~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/crop_layer.c -o obj/crop_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/dropout_layer.c -o obj/dropout_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/maxpool_layer.c -o obj/maxpool_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/softmax_layer.c -o obj/softmax_layer.o
# ./src/softmax_layer.c: In function ‘forward_contrastive_layer’:
# ./src/softmax_layer.c:242:27: warning: variable ‘max_truth’ set but not used [-Wunused-but-set-variable]
#   242 |                     float max_truth = 0;
#       |                           ^~~~~~~~~
# ./src/softmax_layer.c:421:71: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘size_t’ {aka ‘long unsigned int’} [-Wformat=]
#   421 |             printf(" Error: too large number of bboxes: contr_size = %d > max_contr_size  = %d \n", contr_size, max_contr_size);
#       |                                                                      ~^                             ~~~~~~~~~~
#       |                                                                       |                             |
#       |                                                                       int                           size_t {aka long unsigned int}
#       |                                                                      %ld
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/data.c -o obj/data.o
# ./src/data.c: In function ‘load_data_detection’:
# ./src/data.c:1289:24: warning: unused variable ‘x’ [-Wunused-variable]
#  1289 |                 int k, x, y;
#       |                        ^
# ./src/data.c:1076:43: warning: variable ‘r_scale’ set but not used [-Wunused-but-set-variable]
#  1076 |     float r1 = 0, r2 = 0, r3 = 0, r4 = 0, r_scale = 0;
#       |                                           ^~~~~~~
# ./src/data.c: In function ‘fill_truth_detection’:
# ./src/data.c:431:33: warning: ‘%s’ directive writing up to 4095 bytes into a region of size 251 [-Wformat-overflow=]
#   431 |             sprintf(buff, "echo %s \"Wrong annotation: w = %f\" >> bad_label.list", labelpath, w);
#       |                                 ^~                                                  ~~~~~~~~~
# ./src/data.c:431:27: note: assuming directive output of 8 bytes
#   431 |             sprintf(buff, "echo %s \"Wrong annotation: w = %f\" >> bad_label.list", labelpath, w);
#       |                           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# In file included from /usr/include/stdio.h:894,
#                  from include/darknet.h:13,
#                  from ./src/data.h:5,
#                  from ./src/data.c:1:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:38:10: note: ‘__builtin___sprintf_chk’ output between 52 and 4461 bytes into a destination of size 256
#    38 |   return __builtin___sprintf_chk (__s, __USE_FORTIFY_LEVEL - 1,
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    39 |                                   __glibc_objsize (__s), __fmt,
#       |                                   ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    40 |                                   __va_arg_pack ());
#       |                                   ~~~~~~~~~~~~~~~~~
# ./src/data.c:437:33: warning: ‘%s’ directive writing up to 4095 bytes into a region of size 251 [-Wformat-overflow=]
#   437 |             sprintf(buff, "echo %s \"Wrong annotation: h = %f\" >> bad_label.list", labelpath, h);
#       |                                 ^~                                                  ~~~~~~~~~
# ./src/data.c:437:27: note: assuming directive output of 8 bytes
#   437 |             sprintf(buff, "echo %s \"Wrong annotation: h = %f\" >> bad_label.list", labelpath, h);
#       |                           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# In file included from /usr/include/stdio.h:894,
#                  from include/darknet.h:13,
#                  from ./src/data.h:5,
#                  from ./src/data.c:1:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:38:10: note: ‘__builtin___sprintf_chk’ output between 52 and 4461 bytes into a destination of size 256
#    38 |   return __builtin___sprintf_chk (__s, __USE_FORTIFY_LEVEL - 1,
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    39 |                                   __glibc_objsize (__s), __fmt,
#       |                                   ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    40 |                                   __va_arg_pack ());
#       |                                   ~~~~~~~~~~~~~~~~~
# ./src/data.c:424:33: warning: ‘%s’ directive writing up to 4095 bytes into a region of size 251 [-Wformat-overflow=]
#   424 |             sprintf(buff, "echo %s \"Wrong annotation: x = %f, y = %f\" >> bad_label.list", labelpath, x, y);
#       |                                 ^~                                                          ~~~~~~~~~
# ./src/data.c:424:27: note: assuming directive output of 8 bytes
#   424 |             sprintf(buff, "echo %s \"Wrong annotation: x = %f, y = %f\" >> bad_label.list", labelpath, x, y);
#       |                           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ./src/data.c:424:27: note: assuming directive output of 8 bytes
# In file included from /usr/include/stdio.h:894,
#                  from include/darknet.h:13,
#                  from ./src/data.h:5,
#                  from ./src/data.c:1:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:38:10: note: ‘__builtin___sprintf_chk’ output between 61 and 4784 bytes into a destination of size 256
#    38 |   return __builtin___sprintf_chk (__s, __USE_FORTIFY_LEVEL - 1,
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    39 |                                   __glibc_objsize (__s), __fmt,
#       |                                   ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    40 |                                   __va_arg_pack ());
#       |                                   ~~~~~~~~~~~~~~~~~
# ./src/data.c:417:33: warning: ‘%s’ directive writing up to 4095 bytes into a region of size 251 [-Wformat-overflow=]
#   417 |             sprintf(buff, "echo %s \"Wrong annotation: x = 0 or y = 0\" >> bad_label.list", labelpath);
#       |                                 ^~                                                          ~~~~~~~~~
# In file included from /usr/include/stdio.h:894,
#                  from include/darknet.h:13,
#                  from ./src/data.h:5,
#                  from ./src/data.c:1:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:38:10: note: ‘__builtin___sprintf_chk’ output between 59 and 4154 bytes into a destination of size 256
#    38 |   return __builtin___sprintf_chk (__s, __USE_FORTIFY_LEVEL - 1,
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    39 |                                   __glibc_objsize (__s), __fmt,
#       |                                   ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    40 |                                   __va_arg_pack ());
#       |                                   ~~~~~~~~~~~~~~~~~
# ./src/data.c:404:33: warning: ‘%s’ directive writing up to 4095 bytes into a region of size 251 [-Wformat-overflow=]
#   404 |             sprintf(buff, "echo %s \"Wrong annotation: class_id = %d. But class_id should be [from 0 to %d]\" >> bad_label.list", labelpath, id, (classes-1));
#       |                                 ^~                                                                                                ~~~~~~~~~
# In file included from /usr/include/stdio.h:894,
#                  from include/darknet.h:13,
#                  from ./src/data.h:5,
#                  from ./src/data.c:1:
# /usr/include/x86_64-linux-gnu/bits/stdio2.h:38:10: note: ‘__builtin___sprintf_chk’ output between 95 and 4210 bytes into a destination of size 256
#    38 |   return __builtin___sprintf_chk (__s, __USE_FORTIFY_LEVEL - 1,
#       |          ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    39 |                                   __glibc_objsize (__s), __fmt,
#       |                                   ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#    40 |                                   __va_arg_pack ());
#       |                                   ~~~~~~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/matrix.c -o obj/matrix.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/network.c -o obj/network.o
# ./src/network.c: In function ‘train_network_waitkey’:
# ./src/network.c:435:13: warning: unused variable ‘ema_period’ [-Wunused-variable]
#   435 |         int ema_period = (net.max_batches - ema_start_point - 1000) * (1.0 - net.ema_alpha);
#       |             ^~~~~~~~~~
# ./src/network.c: In function ‘resize_network’:
# ./src/network.c:660:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#   660 |         if (cudaSuccess == cudaHostAlloc(&net->input_pinned_cpu, size * sizeof(float), cudaHostRegisterMapped))
#       |                                          ^~~~~~~~~~~~~~~~~~~~~~
#       |                                          |
#       |                                          float **
# In file included from /usr/local/cuda/include/cuda_runtime.h:95,
#                  from include/darknet.h:41,
#                  from ./src/network.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:5331:60: note: expected ‘void **’ but argument is of type ‘float **’
#  5331 | extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#       |                                                     ~~~~~~~^~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/connected_layer.c -o obj/connected_layer.o
# ./src/connected_layer.c: In function ‘forward_connected_layer_gpu’:
# ./src/connected_layer.c:346:11: warning: unused variable ‘one’ [-Wunused-variable]
#   346 |     float one = 1;    // alpha[0], beta[0]
#       |           ^~~
# ./src/connected_layer.c:344:13: warning: unused variable ‘c’ [-Wunused-variable]
#   344 |     float * c = l.output_gpu;
#       |             ^
# ./src/connected_layer.c:343:13: warning: unused variable ‘b’ [-Wunused-variable]
#   343 |     float * b = l.weights_gpu;
#       |             ^
# ./src/connected_layer.c:342:13: warning: unused variable ‘a’ [-Wunused-variable]
#   342 |     float * a = state.input;
#       |             ^
# ./src/connected_layer.c:341:9: warning: unused variable ‘n’ [-Wunused-variable]
#   341 |     int n = l.outputs;
#       |         ^
# ./src/connected_layer.c:340:9: warning: unused variable ‘k’ [-Wunused-variable]
#   340 |     int k = l.inputs;
#       |         ^
# ./src/connected_layer.c:339:9: warning: unused variable ‘m’ [-Wunused-variable]
#   339 |     int m = l.batch;
#       |         ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/cost_layer.c -o obj/cost_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/parser.c -o obj/parser.o
# ./src/parser.c: In function ‘parse_network_cfg_custom’:
# ./src/parser.c:1761:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#  1761 |         if (cudaSuccess == cudaHostAlloc(&net.input_pinned_cpu, size * sizeof(float), cudaHostRegisterMapped)) net.input_pinned_cpu_flag = 1;
#       |                                          ^~~~~~~~~~~~~~~~~~~~~
#       |                                          |
#       |                                          float **
# In file included from /usr/local/cuda/include/cuda_runtime.h:95,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/activation_layer.h:4,
#                  from ./src/parser.c:6:
# /usr/local/cuda/include/cuda_runtime_api.h:5331:60: note: expected ‘void **’ but argument is of type ‘float **’
#  5331 | extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#       |                                                     ~~~~~~~^~~~~
# ./src/parser.c: In function ‘save_implicit_weights’:
# ./src/parser.c:1893:9: warning: unused variable ‘i’ [-Wunused-variable]
#  1893 |     int i;
#       |         ^
# ./src/parser.c: In function ‘get_classes_multipliers’:
# ./src/parser.c:435:40: warning: argument 1 range [18446744071562067968, 18446744073709551615] exceeds maximum object size 9223372036854775807 [-Walloc-size-larger-than=]
#   435 |         classes_multipliers = (float *)calloc(classes_counters, sizeof(float));
#       |                                        ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# In file included from ./src/parser.c:3:
# /usr/include/stdlib.h:543:14: note: in a call to allocation function ‘calloc’ declared here
#   543 | extern void *calloc (size_t __nmemb, size_t __size)
#       |              ^~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/option_list.c -o obj/option_list.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/darknet.c -o obj/darknet.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/detection_layer.c -o obj/detection_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/captcha.c -o obj/captcha.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/route_layer.c -o obj/route_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/writing.c -o obj/writing.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/box.c -o obj/box.o
# ./src/box.c: In function ‘box_iou_kind’:
# ./src/box.c:154:5: warning: enumeration value ‘MSE’ not handled in switch [-Wswitch]
#   154 |     switch(iou_kind) {
#       |     ^~~~~~
# ./src/box.c: In function ‘diounms_sort’:
# ./src/box.c:898:27: warning: unused variable ‘beta_prob’ [-Wunused-variable]
#   898 |                     float beta_prob = pow(dets[j].prob[k], 2) / sum_prob;
#       |                           ^~~~~~~~~
# ./src/box.c:897:27: warning: unused variable ‘alpha_prob’ [-Wunused-variable]
#   897 |                     float alpha_prob = pow(dets[i].prob[k], 2) / sum_prob;
#       |                           ^~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/nightmare.c -o obj/nightmare.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/normalization_layer.c -o obj/normalization_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/avgpool_layer.c -o obj/avgpool_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/coco.c -o obj/coco.o
# ./src/coco.c: In function ‘validate_coco_recall’:
# ./src/coco.c:248:11: warning: unused variable ‘base’ [-Wunused-variable]
#   248 |     char *base = "results/comp4_det_test_";
#       |           ^~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/dice.c -o obj/dice.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/yolo.c -o obj/yolo.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/detector.c -o obj/detector.o
# ./src/detector.c: In function ‘eliminate_bdd’:
# ./src/detector.c:585:21: warning: statement with no effect [-Wunused-value]
#   585 |                     for (k; buf[k + n] != '\0'; k++)
#       |                     ^~~
# ./src/detector.c: In function ‘validate_detector’:
# ./src/detector.c:706:13: warning: unused variable ‘mkd2’ [-Wunused-variable]
#   706 |         int mkd2 = make_directory(buff2, 0777);
#       |             ^~~~
# ./src/detector.c:704:13: warning: unused variable ‘mkd’ [-Wunused-variable]
#   704 |         int mkd = make_directory(buff, 0777);
#       |             ^~~
# ./src/detector.c: In function ‘validate_detector_map’:
# ./src/detector.c:1323:24: warning: variable ‘cur_prob’ set but not used [-Wunused-but-set-variable]
#  1323 |                 double cur_prob = 0;
#       |                        ^~~~~~~~
# ./src/detector.c:1344:15: warning: unused variable ‘class_recall’ [-Wunused-variable]
#  1344 |         float class_recall = (float)tp_for_thresh_per_class[i] / ((float)tp_for_thresh_per_class[i] + (float)(truth_classes_count[i] - tp_for_thresh_per_class[i]));
#       |               ^~~~~~~~~~~~
# ./src/detector.c:1343:15: warning: unused variable ‘class_precision’ [-Wunused-variable]
#  1343 |         float class_precision = (float)tp_for_thresh_per_class[i] / ((float)tp_for_thresh_per_class[i] + (float)fp_for_thresh_per_class[i]);
#       |               ^~~~~~~~~~~~~~~
# ./src/detector.c: In function ‘draw_object’:
# ./src/detector.c:1872:19: warning: unused variable ‘inv_loss’ [-Wunused-variable]
#  1872 |             float inv_loss = 1.0 / max_val_cmp(0.01, avg_loss);
#       |                   ^~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/layer.c -o obj/layer.o
# ./src/layer.c: In function ‘free_layer_custom’:
# ./src/layer.c:208:68: warning: suggest parentheses around ‘&&’ within ‘||’ [-Wparentheses]
#   208 |     if (l.delta_gpu && (l.optimized_memory < 1 || l.keep_delta_gpu && l.optimized_memory < 3)) cuda_free(l.delta_gpu), l.delta_gpu = NULL;
#       |                                                   ~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/compare.c -o obj/compare.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/classifier.c -o obj/classifier.o
# ./src/classifier.c: In function ‘train_classifier’:
# ./src/classifier.c:146:9: warning: unused variable ‘count’ [-Wunused-variable]
#   146 |     int count = 0;
#       |         ^~~~~
# ./src/classifier.c: In function ‘predict_classifier’:
# ./src/classifier.c:855:13: warning: unused variable ‘time’ [-Wunused-variable]
#   855 |     clock_t time;
#       |             ^~~~
# ./src/classifier.c: In function ‘demo_classifier’:
# ./src/classifier.c:1283:49: warning: unused variable ‘tval_result’ [-Wunused-variable]
#  1283 |         struct timeval tval_before, tval_after, tval_result;
#       |                                                 ^~~~~~~~~~~
# ./src/classifier.c:1283:37: warning: unused variable ‘tval_after’ [-Wunused-variable]
#  1283 |         struct timeval tval_before, tval_after, tval_result;
#       |                                     ^~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/local_layer.c -o obj/local_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/swag.c -o obj/swag.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/shortcut_layer.c -o obj/shortcut_layer.o
# ./src/shortcut_layer.c: In function ‘make_shortcut_layer’:
# ./src/shortcut_layer.c:55:15: warning: unused variable ‘scale’ [-Wunused-variable]
#    55 |         float scale = sqrt(2. / l.nweights);
#       |               ^~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/representation_layer.c -o obj/representation_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/activation_layer.c -o obj/activation_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/rnn_layer.c -o obj/rnn_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/gru_layer.c -o obj/gru_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/rnn.c -o obj/rnn.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/rnn_vid.c -o obj/rnn_vid.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/crnn_layer.c -o obj/crnn_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/demo.c -o obj/demo.o
# ./src/demo.c: In function ‘detect_in_thread’:
# ./src/demo.c:100:15: warning: unused variable ‘l’ [-Wunused-variable]
#   100 |         layer l = net.layers[net.n - 1];
#       |               ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/tag.c -o obj/tag.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/cifar.c -o obj/cifar.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/go.c -o obj/go.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/batchnorm_layer.c -o obj/batchnorm_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/art.c -o obj/art.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/region_layer.c -o obj/region_layer.o
# ./src/region_layer.c: In function ‘resize_region_layer’:
# ./src/region_layer.c:63:9: warning: unused variable ‘old_h’ [-Wunused-variable]
#    63 |     int old_h = l->h;
#       |         ^~~~~
# ./src/region_layer.c:62:9: warning: unused variable ‘old_w’ [-Wunused-variable]
#    62 |     int old_w = l->w;
#       |         ^~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/reorg_layer.c -o obj/reorg_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/reorg_old_layer.c -o obj/reorg_old_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/super.c -o obj/super.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/voxel.c -o obj/voxel.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/tree.c -o obj/tree.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/yolo_layer.c -o obj/yolo_layer.o
# ./src/yolo_layer.c: In function ‘make_yolo_layer’:
# ./src/yolo_layer.c:67:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#    67 |     if (cudaSuccess == cudaHostAlloc(&l.output, batch*l.outputs*sizeof(float), cudaHostRegisterMapped)) l.output_pinned = 1;
#       |                                      ^~~~~~~~~
#       |                                      |
#       |                                      float **
# In file included from /usr/local/cuda/include/cuda_runtime.h:95,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:5331:60: note: expected ‘void **’ but argument is of type ‘float **’
#  5331 | extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#       |                                                     ~~~~~~~^~~~~
# ./src/yolo_layer.c:74:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#    74 |     if (cudaSuccess == cudaHostAlloc(&l.delta, batch*l.outputs*sizeof(float), cudaHostRegisterMapped)) l.delta_pinned = 1;
#       |                                      ^~~~~~~~
#       |                                      |
#       |                                      float **
# In file included from /usr/local/cuda/include/cuda_runtime.h:95,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:5331:60: note: expected ‘void **’ but argument is of type ‘float **’
#  5331 | extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#       |                                                     ~~~~~~~^~~~~
# ./src/yolo_layer.c: In function ‘resize_yolo_layer’:
# ./src/yolo_layer.c:105:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#   105 |         if (cudaSuccess != cudaHostAlloc(&l->output, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#       |                                          ^~~~~~~~~~
#       |                                          |
#       |                                          float **
# In file included from /usr/local/cuda/include/cuda_runtime.h:95,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:5331:60: note: expected ‘void **’ but argument is of type ‘float **’
#  5331 | extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#       |                                                     ~~~~~~~^~~~~
# ./src/yolo_layer.c:114:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#   114 |         if (cudaSuccess != cudaHostAlloc(&l->delta, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#       |                                          ^~~~~~~~~
#       |                                          |
#       |                                          float **
# In file included from /usr/local/cuda/include/cuda_runtime.h:95,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:5331:60: note: expected ‘void **’ but argument is of type ‘float **’
#  5331 | extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#       |                                                     ~~~~~~~^~~~~
# ./src/yolo_layer.c: In function ‘process_batch’:
# ./src/yolo_layer.c:425:25: warning: variable ‘best_match_t’ set but not used [-Wunused-but-set-variable]
#   425 |                     int best_match_t = 0;
#       |                         ^~~~~~~~~~~~
# ./src/yolo_layer.c: In function ‘forward_yolo_layer’:
# ./src/yolo_layer.c:705:11: warning: unused variable ‘avg_anyobj’ [-Wunused-variable]
#   705 |     float avg_anyobj = 0;
#       |           ^~~~~~~~~~
# ./src/yolo_layer.c:704:11: warning: unused variable ‘avg_obj’ [-Wunused-variable]
#   704 |     float avg_obj = 0;
#       |           ^~~~~~~
# ./src/yolo_layer.c:703:11: warning: unused variable ‘avg_cat’ [-Wunused-variable]
#   703 |     float avg_cat = 0;
#       |           ^~~~~~~
# ./src/yolo_layer.c:702:11: warning: unused variable ‘recall75’ [-Wunused-variable]
#   702 |     float recall75 = 0;
#       |           ^~~~~~~~
# ./src/yolo_layer.c:701:11: warning: unused variable ‘recall’ [-Wunused-variable]
#   701 |     float recall = 0;
#       |           ^~~~~~
# ./src/yolo_layer.c:700:11: warning: unused variable ‘tot_ciou_loss’ [-Wunused-variable]
#   700 |     float tot_ciou_loss = 0;
#       |           ^~~~~~~~~~~~~
# ./src/yolo_layer.c:699:11: warning: unused variable ‘tot_diou_loss’ [-Wunused-variable]
#   699 |     float tot_diou_loss = 0;
#       |           ^~~~~~~~~~~~~
# ./src/yolo_layer.c:696:11: warning: unused variable ‘tot_ciou’ [-Wunused-variable]
#   696 |     float tot_ciou = 0;
#       |           ^~~~~~~~
# ./src/yolo_layer.c:695:11: warning: unused variable ‘tot_diou’ [-Wunused-variable]
#   695 |     float tot_diou = 0;
#       |           ^~~~~~~~
# ./src/yolo_layer.c:694:11: warning: unused variable ‘tot_giou’ [-Wunused-variable]
#   694 |     float tot_giou = 0;
#       |           ^~~~~~~~
# ./src/yolo_layer.c:666:12: warning: unused variable ‘n’ [-Wunused-variable]
#   666 |     int b, n;
#       |            ^
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/gaussian_yolo_layer.c -o obj/gaussian_yolo_layer.o
# ./src/gaussian_yolo_layer.c: In function ‘make_gaussian_yolo_layer’:
# ./src/gaussian_yolo_layer.c:70:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#    70 |     if (cudaSuccess == cudaHostAlloc(&l.output, batch*l.outputs * sizeof(float), cudaHostRegisterMapped)) l.output_pinned = 1;
#       |                                      ^~~~~~~~~
#       |                                      |
#       |                                      float **
# In file included from /usr/local/cuda/include/cuda_runtime.h:95,
#                  from include/darknet.h:41,
#                  from ./src/gaussian_yolo_layer.h:5,
#                  from ./src/gaussian_yolo_layer.c:7:
# /usr/local/cuda/include/cuda_runtime_api.h:5331:60: note: expected ‘void **’ but argument is of type ‘float **’
#  5331 | extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#       |                                                     ~~~~~~~^~~~~
# ./src/gaussian_yolo_layer.c:77:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#    77 |     if (cudaSuccess == cudaHostAlloc(&l.delta, batch*l.outputs * sizeof(float), cudaHostRegisterMapped)) l.delta_pinned = 1;
#       |                                      ^~~~~~~~
#       |                                      |
#       |                                      float **
# In file included from /usr/local/cuda/include/cuda_runtime.h:95,
#                  from include/darknet.h:41,
#                  from ./src/gaussian_yolo_layer.h:5,
#                  from ./src/gaussian_yolo_layer.c:7:
# /usr/local/cuda/include/cuda_runtime_api.h:5331:60: note: expected ‘void **’ but argument is of type ‘float **’
#  5331 | extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#       |                                                     ~~~~~~~^~~~~
# ./src/gaussian_yolo_layer.c: In function ‘resize_gaussian_yolo_layer’:
# ./src/gaussian_yolo_layer.c:109:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#   109 |         if (cudaSuccess != cudaHostAlloc(&l->output, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#       |                                          ^~~~~~~~~~
#       |                                          |
#       |                                          float **
# In file included from /usr/local/cuda/include/cuda_runtime.h:95,
#                  from include/darknet.h:41,
#                  from ./src/gaussian_yolo_layer.h:5,
#                  from ./src/gaussian_yolo_layer.c:7:
# /usr/local/cuda/include/cuda_runtime_api.h:5331:60: note: expected ‘void **’ but argument is of type ‘float **’
#  5331 | extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#       |                                                     ~~~~~~~^~~~~
# ./src/gaussian_yolo_layer.c:118:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#   118 |         if (cudaSuccess != cudaHostAlloc(&l->delta, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#       |                                          ^~~~~~~~~
#       |                                          |
#       |                                          float **
# In file included from /usr/local/cuda/include/cuda_runtime.h:95,
#                  from include/darknet.h:41,
#                  from ./src/gaussian_yolo_layer.h:5,
#                  from ./src/gaussian_yolo_layer.c:7:
# /usr/local/cuda/include/cuda_runtime_api.h:5331:60: note: expected ‘void **’ but argument is of type ‘float **’
#  5331 | extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#       |                                                     ~~~~~~~^~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/upsample_layer.c -o obj/upsample_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/lstm_layer.c -o obj/lstm_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/conv_lstm_layer.c -o obj/conv_lstm_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/scale_channels_layer.c -o obj/scale_channels_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/sam_layer.c -o obj/sam_layer.o
# nvcc -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/convolutional_kernels.cu -o obj/convolutional_kernels.o
# nvcc -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/activation_kernels.cu -o obj/activation_kernels.o
# nvcc -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/im2col_kernels.cu -o obj/im2col_kernels.o
# nvcc -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/col2im_kernels.cu -o obj/col2im_kernels.o
# nvcc -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/blas_kernels.cu -o obj/blas_kernels.o
# nvcc -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/crop_layer_kernels.cu -o obj/crop_layer_kernels.o
# nvcc -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/dropout_layer_kernels.cu -o obj/dropout_layer_kernels.o
# nvcc -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/maxpool_layer_kernels.cu -o obj/maxpool_layer_kernels.o
# nvcc -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/network_kernels.cu -o obj/network_kernels.o
# nvcc -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include" -c ./src/avgpool_layer_kernels.cu -o obj/avgpool_layer_kernels.o
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -rdynamic -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include obj/image_opencv.o obj/http_stream.o obj/gemm.o obj/utils.o obj/dark_cuda.o obj/convolutional_layer.o obj/list.o obj/image.o obj/activations.o obj/im2col.o obj/col2im.o obj/blas.o obj/crop_layer.o obj/dropout_layer.o obj/maxpool_layer.o obj/softmax_layer.o obj/data.o obj/matrix.o obj/network.o obj/connected_layer.o obj/cost_layer.o obj/parser.o obj/option_list.o obj/darknet.o obj/detection_layer.o obj/captcha.o obj/route_layer.o obj/writing.o obj/box.o obj/nightmare.o obj/normalization_layer.o obj/avgpool_layer.o obj/coco.o obj/dice.o obj/yolo.o obj/detector.o obj/layer.o obj/compare.o obj/classifier.o obj/local_layer.o obj/swag.o obj/shortcut_layer.o obj/representation_layer.o obj/activation_layer.o obj/rnn_layer.o obj/gru_layer.o obj/rnn.o obj/rnn_vid.o obj/crnn_layer.o obj/demo.o obj/tag.o obj/cifar.o obj/go.o obj/batchnorm_layer.o obj/art.o obj/region_layer.o obj/reorg_layer.o obj/reorg_old_layer.o obj/super.o obj/voxel.o obj/tree.o obj/yolo_layer.o obj/gaussian_yolo_layer.o obj/upsample_layer.o obj/lstm_layer.o obj/conv_lstm_layer.o obj/scale_channels_layer.o obj/sam_layer.o obj/convolutional_kernels.o obj/activation_kernels.o obj/im2col_kernels.o obj/col2im_kernels.o obj/blas_kernels.o obj/crop_layer_kernels.o obj/dropout_layer_kernels.o obj/maxpool_layer_kernels.o obj/network_kernels.o obj/avgpool_layer_kernels.o -o darknet -lm -pthread `pkg-config --libs opencv4 2> /dev/null || pkg-config --libs opencv` -L/usr/local/cuda/lib64 -lcuda -lcudart -lcublas -lcurand -L/usr/local/cudnn/lib64 -lcudnn -lstdc++

# %% [markdown]
# # 2. Helper 함수 정의
# 업로드, 다운로드, imShow등과 관련된 함수 정의

# %%
# helper함수들
def imShow(path):
  import cv2
  import matplotlib.pyplot as plt
  # %matplotlib inline

  image = cv2.imread(path)  #경로로부터 이미지를 불러읽어들여서
  height, width = image.shape[:2]   #현재 영상의 height와 width를 읽어서
  resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC) #영상을 3배로 키운다(크게 보여주기 위해서)

  fig = plt.gcf()
  fig.set_size_inches(18, 10)
  plt.axis("off")
  plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))  #opencv로 읽어들인 영상은 BGR포맷을 갖기 때문에 RGB포맷으로 변환해야 함
  plt.show()

# google colab으로 파일을 업로드할 때 사용하는 함수를 정의
def upload():
  from google.colab import files
  uploaded = files.upload()
  for name, data in uploaded.items():
    with open(name, 'wb') as f:
      f.write(data)
      print ('saved file', name)

# google colab에서 파일을 다운로드할 때 사용하는 함수를 정의
def download(path):
  from google.colab import files
  files.download(path)

# %%
# %cd ..
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# /content
# Mounted at /content/gdrive

# %%
# 다음은 /content/gdrive/My\ Drive/ 의 경로를 /mydrive 로 접근할 수 있도록 링크를 만들어준다.
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
# 'Colab Notebooks'  'My Drive'   yolov3

# %% [markdown]
# # 3. 클라우드에서 커스텀 YOLOv3 Object Detector를 학습시키기
#
# 커스텀 YOLOv3 detector를 학습하려면 다음이 필요하다:
#
# *   라벨을 가진 커스텀 데이터셋
# *   커스텀 .cfg file
# *   obj.data 와 obj.names 파일들
# *   train.txt file (test.txt 는 있어도 되고 없어도 됨)

# %% [markdown]
# # Step 1: 커스텀 데이터셋 마련
#
# 커스텀 custom object detector를 만들려면 이미지와 라벨을 가진 데이터셋을 마련해야 한다.
#
# 다음의 2가지 방법을 이용할 수 있다.

# %% [markdown]
# ### 방법 1: 구글의 Open Images Dataset을 이용하기
#
# 구글의 Open Images Dataset에서 데이터셋을 얻어서 OIDv4 toolkit 등으로 라벨을 생성하는 방법은 쉽고 빠르다. 구글의 Open Images Dataset은 600개가 넘는 클래스들에 대하여 라벨링이 된 이미지들을 가지고 있다.
#  [여기서 데이터셋을 찾아보기](https://storage.googleapis.com/openimages/web/index.html)
#
# 다음 비디오에는 구글의 Open Images Dataset을 이용하여 자신만의 커스텀 데이터셋을 만드는 방법에 대해 설명하고 있다:
#
# [Creating a Custom YOLOv3 Dataset (Video)](https://www.youtube.com/watch?v=_4A9inxGqRM)
#
# 다음 링크는 OIDv4 toolkit!에 대한 Gihub의 repository에 대한 링크임: [Github Repo](https://github.com/theAIGuysCode/OIDv4_ToolKit)
#
# 이 튜토리얼에서는 구글의 Open Images Dataset을 이용하여 safari animal object detector를 위한 이미지 데이터셋을 만들고자 한다.
# OIDv4 toolkit안에서 다음의 코멘드를 실행한다.
#
# ```
# python main.py downloader --classes Elephant Giraffe Hippopotamus Tiger Zebra --type_csv train --limit 300 --multiclasses 1
# ```
#
# 그러면 Elephant, Giraffe, Hippopotamus, Tiger, Zebra의 영상들이 하나의 폴더에 들어가게 된다. 각 클래스에 대해 300개의 이미지가 생겨서 전체적으로는 1500개의 영상이 하나의 폴더안에 생기게 된다.
#
# OIDv4_ToolKit의 root folder폴더에서 classes.txt라는 파일을 열고 다음과 같이 각 라인에 클래스명을 하나씩 적어놓는다.
# ![image.png](data:image/png;base64,...)
#
# 이제 다음의 명령문으로 이미지의 annotation을 변환시키면 됨:
# ```
# python convert_annotations.py
# ```
# 위의 명령문은 모든 라벨을 YOLOv3에서 사용하는 포맷으로 변환시켜서 커스텀 object detector를 학습시킬 수 있는 형태가 되게 한다.
#
# OIDv4 toolkit의 옛날 'Label' 폴더 제거하기:
# 다음 명령문을 실행하여 YOLOv3에서 사용하지 못하는 라벨을 제거한다: (경로명은 어떤 클래스를 다운로드를 받았는지에 따라 달라진다.
# ```
# rm -r OID/Dataset/train/Elephant_Giraffe_Hippopotamus_Tiger_Zebra/Label/
# ```
# 위의 명령어가 먹히지 않으면 직접 'Label'이라는 폴더를 찾아서 제거해도 된다.
#
# 모든 이미지와 annotation을 포함하는 폴더의 내용은 다음과 같게 된다. 여기서 각 이미지 이름과 같은 텍스트 파일이 쌍으로 생김을 볼 수 있다.
#
# ![image.png](data:image/png;base64,...)
#
# ## 여기까지 하면 커스텀 YOLOv3 dataset의 생성이 완료된 것임.

# %% [markdown]
# ### 방법 2: Annotation Tool을 사용하여 수동으로 annotation을 만들기
#
# 만약 구글의 Open Images Dataset에 적당한 이미지나 클래스를 찾을 수 없다면 수동으로 라벨을 그리는 방법이 있다. 이 방법은 상당히 노력이 필요한 방법이다.
#
# 밑의 유튜브는 annotation tool인 LabelImg를 사용하여 YOLOv3를 위한 커스텀 데이터셋을 만드는 방법을 설명하고 있다.
#
# [Create Labels and Annotations for Custom YOLOv3 Dataset (Video)](https://www.youtube.com/watch?v=EGQyDla8JNU)
#
# 위의 튜터리얼 영상을 따라하면 마찬가지로 이미지와 텍스트파일이 존재하는 폴더가 생길 것이다.
#
# ## 여기까지 하면 커스텀 YOLOv3 dataset의 생성이 완료된 것임.

# %% [markdown]
# # Step 2: 커스텀 데이터셋을 클라우드에 올리기
#
# 데이터셋의 포맷을 학습하기에 적합하도록 변환한 후에는 데이터셋을 클라우드에 올려야 한다.
#
# 이미지와 텍스트 파일이 있는 폴더명을  '**obj**' 라고 한 다음에 'obj' 폴더를 zip파일로 압축하여 클라우드로 업로드하고 클라우드에서 zip파일을 압축풀기하면 된다.

# %%
# 압축한 zip파일을 넣은 폴더
# !ls /mydrive/yolov3
# Out:
# backup	generate_train.py  obj.data  obj.names	obj.zip  yolov3_custom.cfg

# %%
cd darknet
# Out:
# /content/darknet

# %%
# obj.zip파일을 클라우드의 root directory로 copy하기
# !cp /mydrive/yolov3/obj.zip ../

# %%
# !ls
# Out:
# 3rdparty	darknet			Dockerfile.cpu	       Makefile       scripts
# backup		DarknetConfig.cmake.in	Dockerfile.gpu	       net_cam_v3.sh  src
# build		darknet_images.py	image_yolov3.sh        net_cam_v4.sh  vcpkg.json
# build.ps1	darknet.py		image_yolov4.sh        obj	      vcpkg.json.opencv23
# cfg		darknet_video.py	include		       package.xml    video_yolov3.sh
# cmake		data			json_mjpeg_streams.sh  README.md      video_yolov4.sh
# CMakeLists.txt	docker-compose.yml	LICENSE		       results

# %%
# 다음과 같이 zip파일을 압축풀기하면 파일안의 내용들이 /darknet/data/obj 안에 있게 된다
# !unzip ../obj.zip -d data/obj/
# Out:
# Archive:  ../obj.zip
#   inflating: data/obj/0004fca29aa55afd.jpg
#   inflating: data/obj/0004fca29aa55afd.txt
#   inflating: data/obj/001865dde032bd93.jpg
#   inflating: data/obj/001865dde032bd93.txt
#   inflating: data/obj/002ee58203ad4236.jpg
#   inflating: data/obj/002ee58203ad4236.txt
#   inflating: data/obj/00564eed612fc8b1.jpg
#   inflating: data/obj/00564eed612fc8b1.txt
#   inflating: data/obj/00582a2c41808125.jpg
#   inflating: data/obj/00582a2c41808125.txt
#   inflating: data/obj/0060cffdaf185235.jpg
#   inflating: data/obj/0060cffdaf185235.txt
#   inflating: data/obj/00878d1c9e01224e.jpg
#   inflating: data/obj/00878d1c9e01224e.txt
#   inflating: data/obj/00c8df7ab3eb481b.jpg
#   inflating: data/obj/00c8df7ab3eb481b.txt
#   inflating: data/obj/00cbfadf1eef3f32.jpg
#   inflating: data/obj/00cbfadf1eef3f32.txt
#   inflating: data/obj/00d159ae851fcb7d.jpg
#   inflating: data/obj/00d159ae851fcb7d.txt
#   inflating: data/obj/013bbf863c523d54.jpg
#   inflating: data/obj/013bbf863c523d54.txt
#   inflating: data/obj/01598092a0c67fdf.jpg
#   inflating: data/obj/01598092a0c67fdf.txt
#   inflating: data/obj/015be535cffc9ecd.jpg
#   inflating: data/obj/015be535cffc9ecd.txt
#   inflating: data/obj/01680c2a956e4be2.jpg
#   inflating: data/obj/01680c2a956e4be2.txt
#   inflating: data/obj/016aa0f5b312e108.jpg
#   inflating: data/obj/016aa0f5b312e108.txt
#   inflating: data/obj/016c7526835c386e.jpg
#   inflating: data/obj/016c7526835c386e.txt
#   inflating: data/obj/0175c0aef4065588.jpg
#   inflating: data/obj/0175c0aef4065588.txt
#   inflating: data/obj/017fe75722510594.jpg
#   inflating: data/obj/017fe75722510594.txt
#   inflating: data/obj/019acf832da28d45.jpg
#   inflating: data/obj/019acf832da28d45.txt
#   inflating: data/obj/01a59c3a13c31b94.jpg
#   inflating: data/obj/01a59c3a13c31b94.txt
#   inflating: data/obj/01f6776d6df56807.jpg
#   inflating: data/obj/01f6776d6df56807.txt
#   inflating: data/obj/02337ff39f54d027.jpg
#   inflating: data/obj/02337ff39f54d027.txt
#   inflating: data/obj/0297d5074ac0fda8.jpg
#   inflating: data/obj/0297d5074ac0fda8.txt
#   inflating: data/obj/02d90a4b3c9fd651.jpg
#   inflating: data/obj/02d90a4b3c9fd651.txt
#   inflating: data/obj/0330c335c5c9c125.jpg
#   inflating: data/obj/0330c335c5c9c125.txt
#   inflating: data/obj/033363df92aab0bc.jpg
#   inflating: data/obj/033363df92aab0bc.txt
#   inflating: data/obj/034fb23feb138388.jpg
#   inflating: data/obj/034fb23feb138388.txt
#   inflating: data/obj/0384258aaa5d934b.jpg
#   inflating: data/obj/0384258aaa5d934b.txt
#   inflating: data/obj/03d850aab21c3ad7.jpg
#   inflating: data/obj/03d850aab21c3ad7.txt
#   inflating: data/obj/040f384c6b25af02.jpg
#   inflating: data/obj/040f384c6b25af02.txt
#   inflating: data/obj/047c02c604371097.jpg
#   inflating: data/obj/047c02c604371097.txt
#   inflating: data/obj/04e18b2ff5c1c6f5.jpg
#   inflating: data/obj/04e18b2ff5c1c6f5.txt
#   inflating: data/obj/0519b821e37453e8.jpg
#   inflating: data/obj/0519b821e37453e8.txt
#   inflating: data/obj/053b60b58708e9d0.jpg
#   inflating: data/obj/053b60b58708e9d0.txt
#   inflating: data/obj/05702f4a18d331e6.jpg
#   inflating: data/obj/05702f4a18d331e6.txt
#   inflating: data/obj/059ae0405fa8b79a.jpg
#   inflating: data/obj/059ae0405fa8b79a.txt
#   inflating: data/obj/059f12fcf66c7bab.jpg
#   inflating: data/obj/059f12fcf66c7bab.txt
#   inflating: data/obj/05c903be07a62988.jpg
#   inflating: data/obj/05c903be07a62988.txt
#   inflating: data/obj/068bc41b03515998.jpg
#   inflating: data/obj/068bc41b03515998.txt
#   inflating: data/obj/070699df21e41bbe.jpg
#   inflating: data/obj/070699df21e41bbe.txt
#   inflating: data/obj/070b4071b79a9326.jpg
#   inflating: data/obj/070b4071b79a9326.txt
#   inflating: data/obj/071c5eba8613ce17.jpg
#   inflating: data/obj/071c5eba8613ce17.txt
#   inflating: data/obj/072792712d3b96e4.jpg
#   inflating: data/obj/072792712d3b96e4.txt
#   inflating: data/obj/07a443c74b3a9351.jpg
#   inflating: data/obj/07a443c74b3a9351.txt
#   inflating: data/obj/082cc627aee9f3d7.jpg
#   inflating: data/obj/082cc627aee9f3d7.txt
#   inflating: data/obj/09d813119bf5d2b6.jpg
#   inflating: data/obj/09d813119bf5d2b6.txt
#   inflating: data/obj/0aabcf5f5332b8a7.jpg
#   inflating: data/obj/0aabcf5f5332b8a7.txt
#   inflating: data/obj/0b94ee8f3389d13e.jpg
#   inflating: data/obj/0b94ee8f3389d13e.txt
#   inflating: data/obj/0c0ab8ca306a2bf2.jpg
#   inflating: data/obj/0c0ab8ca306a2bf2.txt
#   inflating: data/obj/0cb7b11cedbc5be2.jpg
#   inflating: data/obj/0cb7b11cedbc5be2.txt
#   inflating: data/obj/0cfb50b79065c8dd.jpg
#   inflating: data/obj/0cfb50b79065c8dd.txt
#   inflating: data/obj/0d35dc7956b0ba17.jpg
#   inflating: data/obj/0d35dc7956b0ba17.txt
#   inflating: data/obj/0d6ba14c36a9dc43.jpg
#   inflating: data/obj/0d6ba14c36a9dc43.txt
#   inflating: data/obj/0d8577e4e5b593e7.jpg
#   inflating: data/obj/0d8577e4e5b593e7.txt
#   inflating: data/obj/0ddf07798d2e5b01.jpg
#   inflating: data/obj/0ddf07798d2e5b01.txt
#   inflating: data/obj/0e21f007879deb66.jpg
#   inflating: data/obj/0e21f007879deb66.txt
#   inflating: data/obj/0eba77ac2d3b4e82.jpg
#   inflating: data/obj/0eba77ac2d3b4e82.txt
#   inflating: data/obj/0ef868360a6fd73c.jpg
#   inflating: data/obj/0ef868360a6fd73c.txt
#   inflating: data/obj/0f12fd34038b9047.jpg
#   inflating: data/obj/0f12fd34038b9047.txt
#   inflating: data/obj/0f970cde071ca351.jpg
#   inflating: data/obj/0f970cde071ca351.txt
#   inflating: data/obj/0fdaf044f3f955b6.jpg
#   inflating: data/obj/0fdaf044f3f955b6.txt
#   inflating: data/obj/0fe0c1730ac8a8f3.jpg
#   inflating: data/obj/0fe0c1730ac8a8f3.txt
#   inflating: data/obj/10b3d253887e9b76.jpg
#   inflating: data/obj/10b3d253887e9b76.txt
#   inflating: data/obj/1112aeb0f3a1bc76.jpg
#   inflating: data/obj/1112aeb0f3a1bc76.txt
#   inflating: data/obj/1150d5eaeaa94504.jpg
#   inflating: data/obj/1150d5eaeaa94504.txt
#   inflating: data/obj/1194af13b61f7d5f.jpg
#   inflating: data/obj/1194af13b61f7d5f.txt
#   inflating: data/obj/11f220b5eee85910.jpg
#   inflating: data/obj/11f220b5eee85910.txt
#   inflating: data/obj/121fabbb0522e15b.jpg
#   inflating: data/obj/121fabbb0522e15b.txt
#   inflating: data/obj/132f24eb32409c74.jpg
#   inflating: data/obj/132f24eb32409c74.txt
#   inflating: data/obj/13ab81b828b8443f.jpg
#   inflating: data/obj/13ab81b828b8443f.txt
#   inflating: data/obj/13afb5406f5b9504.jpg
#   inflating: data/obj/13afb5406f5b9504.txt
#   inflating: data/obj/14450cfe5926390a.jpg
#   inflating: data/obj/14450cfe5926390a.txt
#   inflating: data/obj/15c6a1d0f59df5bf.jpg
#   inflating: data/obj/15c6a1d0f59df5bf.txt
#   inflating: data/obj/15e2b8b7b3fcaa9e.jpg
#   inflating: data/obj/15e2b8b7b3fcaa9e.txt
#   inflating: data/obj/161cc760f7150429.jpg
#   inflating: data/obj/161cc760f7150429.txt
#   inflating: data/obj/166b1d9e6c4a591b.jpg
#   inflating: data/obj/166b1d9e6c4a591b.txt
#   inflating: data/obj/16954683239c21aa.jpg
#   inflating: data/obj/16954683239c21aa.txt
#   inflating: data/obj/179d3da6b9ede8f1.jpg
#   inflating: data/obj/179d3da6b9ede8f1.txt
#   inflating: data/obj/1807102148ab8667.jpg
#   inflating: data/obj/1807102148ab8667.txt
#   inflating: data/obj/18b17d63e4e3435c.jpg
#   inflating: data/obj/18b17d63e4e3435c.txt
#   inflating: data/obj/193a3015d5026689.jpg
#   inflating: data/obj/193a3015d5026689.txt
#   inflating: data/obj/1afbbb6e86b074af.jpg
#   inflating: data/obj/1afbbb6e86b074af.txt
#   inflating: data/obj/1b5f7f2e241527ae.jpg
#   inflating: data/obj/1b5f7f2e241527ae.txt
#   inflating: data/obj/1b7926a643653cd8.jpg
#   inflating: data/obj/1b7926a643653cd8.txt
#   inflating: data/obj/1b9608ee513df5ca.jpg
#   inflating: data/obj/1b9608ee513df5ca.txt
#   inflating: data/obj/1c5fcf459ab789eb.jpg
#   inflating: data/obj/1c5fcf459ab789eb.txt
#   inflating: data/obj/1ccdb643e0899fa6.jpg
#   inflating: data/obj/1ccdb643e0899fa6.txt
#   inflating: data/obj/1cd6a4f4590d985e.jpg
#   inflating: data/obj/1cd6a4f4590d985e.txt
#   inflating: data/obj/1cecc2d013260595.jpg
#   inflating: data/obj/1cecc2d013260595.txt
#   inflating: data/obj/1e4b65ed1c08ea2a.jpg
#   inflating: data/obj/1e4b65ed1c08ea2a.txt
#   inflating: data/obj/1ef69f90a8ddeb66.jpg
#   inflating: data/obj/1ef69f90a8ddeb66.txt
#   inflating: data/obj/1f7f97f1d596d2d0.jpg
#   inflating: data/obj/1f7f97f1d596d2d0.txt
#   inflating: data/obj/1fdc406498d39d93.jpg
#   inflating: data/obj/1fdc406498d39d93.txt
#   inflating: data/obj/1fe2a132396c93e5.jpg
#   inflating: data/obj/1fe2a132396c93e5.txt
#   inflating: data/obj/200d5469d4ad0017.jpg
#   inflating: data/obj/200d5469d4ad0017.txt
#   inflating: data/obj/209f099f1aa82da5.jpg
#   inflating: data/obj/209f099f1aa82da5.txt
#   inflating: data/obj/215a9ad09f00ae7b.jpg
#   inflating: data/obj/215a9ad09f00ae7b.txt
#   inflating: data/obj/21deb4c3344ae434.jpg
#   inflating: data/obj/21deb4c3344ae434.txt
#   inflating: data/obj/2211bb6ddb7ef1c6.jpg
#   inflating: data/obj/2211bb6ddb7ef1c6.txt
#   inflating: data/obj/22b9cce2ac6422f7.jpg
#   inflating: data/obj/22b9cce2ac6422f7.txt
#   inflating: data/obj/23615f9a7ac7a56f.jpg
#   inflating: data/obj/23615f9a7ac7a56f.txt
#   inflating: data/obj/237c120fbe05aa37.jpg
#   inflating: data/obj/237c120fbe05aa37.txt
#   inflating: data/obj/23b2395add579025.jpg
#   inflating: data/obj/23b2395add579025.txt
#   inflating: data/obj/24b4255a1ddb6ce1.jpg
#   inflating: data/obj/24b4255a1ddb6ce1.txt
#   inflating: data/obj/2537b5f8ad1de1aa.jpg
#   inflating: data/obj/2537b5f8ad1de1aa.txt
#   inflating: data/obj/255b2cfc59a7bbcc.jpg
#   inflating: data/obj/255b2cfc59a7bbcc.txt
#   inflating: data/obj/2610dd6dcbed7748.jpg
#   inflating: data/obj/2610dd6dcbed7748.txt
#   inflating: data/obj/26a2e553e224e03b.jpg
#   inflating: data/obj/26a2e553e224e03b.txt
#   inflating: data/obj/27430eea30b0b90b.jpg
#   inflating: data/obj/27430eea30b0b90b.txt
#   inflating: data/obj/2745dad3e86bd4ae.jpg
#   inflating: data/obj/2745dad3e86bd4ae.txt
#   inflating: data/obj/27586ef649e6ab27.jpg
#   inflating: data/obj/27586ef649e6ab27.txt
#   inflating: data/obj/28407086a8becf96.jpg
#   inflating: data/obj/28407086a8becf96.txt
#   inflating: data/obj/289f21e59189bde6.jpg
#   inflating: data/obj/289f21e59189bde6.txt
#   inflating: data/obj/294e9184aae5e5e0.jpg
#   inflating: data/obj/294e9184aae5e5e0.txt
#   inflating: data/obj/299ec69292d04f5f.jpg
#   inflating: data/obj/299ec69292d04f5f.txt
#   inflating: data/obj/29de840898201eae.jpg
#   inflating: data/obj/29de840898201eae.txt
#   inflating: data/obj/2a03aa412433c6d7.jpg
#   inflating: data/obj/2a03aa412433c6d7.txt
#   inflating: data/obj/2a08abc408fdd877.jpg
#   inflating: data/obj/2a08abc408fdd877.txt
#   inflating: data/obj/2a1a5349cd3df32d.jpg
#   inflating: data/obj/2a1a5349cd3df32d.txt
#   inflating: data/obj/2a5e821999a72c05.jpg
#   inflating: data/obj/2a5e821999a72c05.txt
#   inflating: data/obj/2b8c05a0f49995c7.jpg
#   inflating: data/obj/2b8c05a0f49995c7.txt
#   inflating: data/obj/2bb736dc57bcb820.jpg
#   inflating: data/obj/2bb736dc57bcb820.txt
#   inflating: data/obj/2d828a2840b6181c.jpg
#   inflating: data/obj/2d828a2840b6181c.txt
#   inflating: data/obj/2d9eb25f5b50dfe6.jpg
#   inflating: data/obj/2d9eb25f5b50dfe6.txt
#   inflating: data/obj/2de0c2d46680ccea.jpg
#   inflating: data/obj/2de0c2d46680ccea.txt
#   inflating: data/obj/2df076ad1db19e75.jpg
#   inflating: data/obj/2df076ad1db19e75.txt
#   inflating: data/obj/2e33b160f0657c15.jpg
#   inflating: data/obj/2e33b160f0657c15.txt
#   inflating: data/obj/2e838d6e84bb20b1.jpg
#   inflating: data/obj/2e838d6e84bb20b1.txt
#   inflating: data/obj/2f5914a30a607c8a.jpg
#   inflating: data/obj/2f5914a30a607c8a.txt
#   inflating: data/obj/2f66def12f4bf6d6.jpg
#   inflating: data/obj/2f66def12f4bf6d6.txt
#   inflating: data/obj/2f75e4732f55bc43.jpg
#   inflating: data/obj/2f75e4732f55bc43.txt
#   inflating: data/obj/306a36e4011502ce.jpg
#   inflating: data/obj/306a36e4011502ce.txt
#   inflating: data/obj/31036413a13eb6b8.jpg
#   inflating: data/obj/31036413a13eb6b8.txt
#   inflating: data/obj/31521cf26675318f.jpg
#   inflating: data/obj/31521cf26675318f.txt
#   inflating: data/obj/31c0581fc9bfacb8.jpg
#   inflating: data/obj/31c0581fc9bfacb8.txt
#   inflating: data/obj/31fab88cb9501d52.jpg
#   inflating: data/obj/31fab88cb9501d52.txt
#   inflating: data/obj/3275d5285de5448c.jpg
#   inflating: data/obj/3275d5285de5448c.txt
#   inflating: data/obj/32cca6fa3d02c285.jpg
#   inflating: data/obj/32cca6fa3d02c285.txt
#   inflating: data/obj/33307d70a1755f5d.jpg
#   inflating: data/obj/33307d70a1755f5d.txt
#   inflating: data/obj/33548a220a6d4d97.jpg
#   inflating: data/obj/33548a220a6d4d97.txt
#   inflating: data/obj/3369f2ecea3062e8.jpg
#   inflating: data/obj/3369f2ecea3062e8.txt
#   inflating: data/obj/3488391cf62ac8d8.jpg
#   inflating: data/obj/3488391cf62ac8d8.txt
#   inflating: data/obj/349ecb37441624bc.jpg
#   inflating: data/obj/349ecb37441624bc.txt
#   inflating: data/obj/34dd75cb69c90784.jpg
#   inflating: data/obj/34dd75cb69c90784.txt
#   inflating: data/obj/34e891bdece5df52.jpg
#   inflating: data/obj/34e891bdece5df52.txt
#   inflating: data/obj/35064b6b20b3937b.jpg
#   inflating: data/obj/35064b6b20b3937b.txt
#   inflating: data/obj/35753339915baf64.jpg
#   inflating: data/obj/35753339915baf64.txt
#   inflating: data/obj/360a7cce9f37abb2.jpg
#   inflating: data/obj/360a7cce9f37abb2.txt
#   inflating: data/obj/36a4baa1c90269a9.jpg
#   inflating: data/obj/36a4baa1c90269a9.txt
#   inflating: data/obj/370c590741d6b3e6.jpg
#   inflating: data/obj/370c590741d6b3e6.txt
#   inflating: data/obj/39075e303166355e.jpg
#   inflating: data/obj/39075e303166355e.txt
#   inflating: data/obj/39527ee76b59255d.jpg
#   inflating: data/obj/39527ee76b59255d.txt
#   inflating: data/obj/39b109938d77d4a2.jpg
#   inflating: data/obj/39b109938d77d4a2.txt
#   inflating: data/obj/3a6a292371d9c62c.jpg
#   inflating: data/obj/3a6a292371d9c62c.txt
#   inflating: data/obj/3a8c85c6e9e0ba00.jpg
#   inflating: data/obj/3a8c85c6e9e0ba00.txt
#   inflating: data/obj/3cf7645fcc6e7f15.jpg
#   inflating: data/obj/3cf7645fcc6e7f15.txt
#   inflating: data/obj/3d8a98193fe961a5.jpg
#   inflating: data/obj/3d8a98193fe961a5.txt
#   inflating: data/obj/3e623fde314632cc.jpg
#   inflating: data/obj/3e623fde314632cc.txt
#   inflating: data/obj/3f07f9c8767da346.jpg
#   inflating: data/obj/3f07f9c8767da346.txt
#   inflating: data/obj/3f16703b058daf25.jpg
#   inflating: data/obj/3f16703b058daf25.txt
#   inflating: data/obj/3f1ca810b35374ac.jpg
#   inflating: data/obj/3f1ca810b35374ac.txt
#   inflating: data/obj/3f2678c2f137d5a8.jpg
#   inflating: data/obj/3f2678c2f137d5a8.txt
#   inflating: data/obj/3fcbf93cbf61b263.jpg
#   inflating: data/obj/3fcbf93cbf61b263.txt
#   inflating: data/obj/3fe2012ae271671b.jpg
#   inflating: data/obj/3fe2012ae271671b.txt
#   inflating: data/obj/40088ea6cc5a78b5.jpg
#   inflating: data/obj/40088ea6cc5a78b5.txt
#   inflating: data/obj/404d92e51549f991.jpg
#   inflating: data/obj/404d92e51549f991.txt
#   inflating: data/obj/40c393a1c59834b5.jpg
#   inflating: data/obj/40c393a1c59834b5.txt
#   inflating: data/obj/40d1f1b266df09ff.jpg
#   inflating: data/obj/40d1f1b266df09ff.txt
#   inflating: data/obj/41130b72473822b1.jpg
#   inflating: data/obj/41130b72473822b1.txt
#   inflating: data/obj/420f084fa960c3ca.jpg
#   inflating: data/obj/420f084fa960c3ca.txt
#   inflating: data/obj/421f951895a0725d.jpg
#   inflating: data/obj/421f951895a0725d.txt
#   inflating: data/obj/4275cf2345fb48e3.jpg
#   inflating: data/obj/4275cf2345fb48e3.txt
#   inflating: data/obj/429e2eb528d78428.jpg
#   inflating: data/obj/429e2eb528d78428.txt
#   inflating: data/obj/42e6ecfce5e461b1.jpg
#   inflating: data/obj/42e6ecfce5e461b1.txt
#   inflating: data/obj/435c47e1f6ef898f.jpg
#   inflating: data/obj/435c47e1f6ef898f.txt
#   inflating: data/obj/43cf29908e02e010.jpg
#   inflating: data/obj/43cf29908e02e010.txt
#   inflating: data/obj/44f860764e47ebcc.jpg
#   inflating: data/obj/44f860764e47ebcc.txt
#   inflating: data/obj/45cc4c56ddfb4912.jpg
#   inflating: data/obj/45cc4c56ddfb4912.txt
#   inflating: data/obj/45ee38f70487de84.jpg
#   inflating: data/obj/45ee38f70487de84.txt
#   inflating: data/obj/46cc86d5b7bcf76b.jpg
#   inflating: data/obj/46cc86d5b7bcf76b.txt
#   inflating: data/obj/473c438fda1b02d0.jpg
#   inflating: data/obj/473c438fda1b02d0.txt
#   inflating: data/obj/477872ad5eede457.jpg
#   inflating: data/obj/477872ad5eede457.txt
#   inflating: data/obj/47e33edae7ec94b3.jpg
#   inflating: data/obj/47e33edae7ec94b3.txt
#   inflating: data/obj/481cae0148bd950a.jpg
#   inflating: data/obj/481cae0148bd950a.txt
#   inflating: data/obj/4944f97314079374.jpg
#   inflating: data/obj/4944f97314079374.txt
#   inflating: data/obj/4952cc3277229b18.jpg
#   inflating: data/obj/4952cc3277229b18.txt
#   inflating: data/obj/49a89ae7d8e7cd68.jpg
#   inflating: data/obj/49a89ae7d8e7cd68.txt
#   inflating: data/obj/49c637a2c5af2a00.jpg
#   inflating: data/obj/49c637a2c5af2a00.txt
#   inflating: data/obj/49f884c112c06500.jpg
#   inflating: data/obj/49f884c112c06500.txt
#   inflating: data/obj/4a574bb6d97c1eb7.jpg
#   inflating: data/obj/4a574bb6d97c1eb7.txt
#   inflating: data/obj/4a934c9cdc81ddc3.jpg
#   inflating: data/obj/4a934c9cdc81ddc3.txt
#   inflating: data/obj/4a9a4110516aa520.jpg
#   inflating: data/obj/4a9a4110516aa520.txt
#   inflating: data/obj/4b37724bcf38a95f.jpg
#   inflating: data/obj/4b37724bcf38a95f.txt
#   inflating: data/obj/4b5bf0347711dbdf.jpg
#   inflating: data/obj/4b5bf0347711dbdf.txt
#   inflating: data/obj/4b69304ec42ae26d.jpg
#   inflating: data/obj/4b69304ec42ae26d.txt
#   inflating: data/obj/4b76af861c0a3e48.jpg
#   inflating: data/obj/4b76af861c0a3e48.txt
#   inflating: data/obj/4c01dcff2cd2775d.jpg
#   inflating: data/obj/4c01dcff2cd2775d.txt
#   inflating: data/obj/4c6aebb0e307dc07.jpg
#   inflating: data/obj/4c6aebb0e307dc07.txt
#   inflating: data/obj/4c7b3f0da95d2670.jpg
#   inflating: data/obj/4c7b3f0da95d2670.txt
#   inflating: data/obj/4d55ae4e6ee95e9f.jpg
#   inflating: data/obj/4d55ae4e6ee95e9f.txt
#   inflating: data/obj/4dc1bb255bb92fe5.jpg
#   inflating: data/obj/4dc1bb255bb92fe5.txt
#   inflating: data/obj/4f33b16e5b45ef7d.jpg
#   inflating: data/obj/4f33b16e5b45ef7d.txt
#   inflating: data/obj/508db43b76890a36.jpg
#   inflating: data/obj/508db43b76890a36.txt
#   inflating: data/obj/50a59e5f257feebc.jpg
#   inflating: data/obj/50a59e5f257feebc.txt
#   inflating: data/obj/50dd2d2ebca438ae.jpg
#   inflating: data/obj/50dd2d2ebca438ae.txt
#   inflating: data/obj/51ac25e8bb370204.jpg
#   inflating: data/obj/51ac25e8bb370204.txt
#   inflating: data/obj/52817a96e0468e95.jpg
#   inflating: data/obj/52817a96e0468e95.txt
#   inflating: data/obj/52ca9c75f8b9656d.jpg
#   inflating: data/obj/52ca9c75f8b9656d.txt
#   inflating: data/obj/54695fcd81219b74.jpg
#   inflating: data/obj/54695fcd81219b74.txt
#   inflating: data/obj/54e8b609f5b5096e.jpg
#   inflating: data/obj/54e8b609f5b5096e.txt
#   inflating: data/obj/55254a2bd68e0b67.jpg
#   inflating: data/obj/55254a2bd68e0b67.txt
#   inflating: data/obj/55371f66fd32bd9f.jpg
#   inflating: data/obj/55371f66fd32bd9f.txt
#   inflating: data/obj/5549dbd6e32b8691.jpg
#   inflating: data/obj/5549dbd6e32b8691.txt
#   inflating: data/obj/5626a8bad4a51274.jpg
#   inflating: data/obj/5626a8bad4a51274.txt
#   inflating: data/obj/5683510f09d3b8be.jpg
#   inflating: data/obj/5683510f09d3b8be.txt
#   inflating: data/obj/56b5bf84054c3a15.jpg
#   inflating: data/obj/56b5bf84054c3a15.txt
#   inflating: data/obj/56dd9e4ad1b8b715.jpg
#   inflating: data/obj/56dd9e4ad1b8b715.txt
#   inflating: data/obj/56f32b2aa278242e.jpg
#   inflating: data/obj/56f32b2aa278242e.txt
#   inflating: data/obj/570eea175c73e325.jpg
#   inflating: data/obj/570eea175c73e325.txt
#   inflating: data/obj/57cbc92d744727e3.jpg
#   inflating: data/obj/57cbc92d744727e3.txt
#   inflating: data/obj/582151e15a8ecd30.jpg
#   inflating: data/obj/582151e15a8ecd30.txt
#   inflating: data/obj/585c104247d79c5c.jpg
#   inflating: data/obj/585c104247d79c5c.txt
#   inflating: data/obj/59777fb912ebe580.jpg
#   inflating: data/obj/59777fb912ebe580.txt
#   inflating: data/obj/59b995d762e1e58a.jpg
#   inflating: data/obj/59b995d762e1e58a.txt
#   inflating: data/obj/5a444d85858d7a64.jpg
#   inflating: data/obj/5a444d85858d7a64.txt
#   inflating: data/obj/5a9a89fd42a55d77.jpg
#   inflating: data/obj/5a9a89fd42a55d77.txt
#   inflating: data/obj/5bc570a10f2edcdd.jpg
#   inflating: data/obj/5bc570a10f2edcdd.txt
#   inflating: data/obj/5bd0e45962593560.jpg
#   inflating: data/obj/5bd0e45962593560.txt
#   inflating: data/obj/5bd9ddc774f3c334.jpg
#   inflating: data/obj/5bd9ddc774f3c334.txt
#   inflating: data/obj/5c022f190711ff35.jpg
#   inflating: data/obj/5c022f190711ff35.txt
#   inflating: data/obj/5c7644a21433e0d5.jpg
#   inflating: data/obj/5c7644a21433e0d5.txt
#   inflating: data/obj/5d4429c521885545.jpg
#   inflating: data/obj/5d4429c521885545.txt
#   inflating: data/obj/5dd477d25ff67085.jpg
#   inflating: data/obj/5dd477d25ff67085.txt
#   inflating: data/obj/5e058aa227ecd893.jpg
#   inflating: data/obj/5e058aa227ecd893.txt
#   inflating: data/obj/5e54e7bf2d44515a.jpg
#   inflating: data/obj/5e54e7bf2d44515a.txt
#   inflating: data/obj/5f34e58a1f3ccd94.jpg
#   inflating: data/obj/5f34e58a1f3ccd94.txt
#   inflating: data/obj/5fa2aa81c88009e5.jpg
#   inflating: data/obj/5fa2aa81c88009e5.txt
#   inflating: data/obj/5fe11d040eb1fa73.jpg
#   inflating: data/obj/5fe11d040eb1fa73.txt
#   inflating: data/obj/60716dc5f7f190c3.jpg
#   inflating: data/obj/60716dc5f7f190c3.txt
#   inflating: data/obj/6082b44edf9215c6.jpg
#   inflating: data/obj/6082b44edf9215c6.txt
#   inflating: data/obj/6111a325525fef38.jpg
#   inflating: data/obj/6111a325525fef38.txt
#   inflating: data/obj/613e8b3ec09ddcb3.jpg
#   inflating: data/obj/613e8b3ec09ddcb3.txt
#   inflating: data/obj/615e0c7f7afab83f.jpg
#   inflating: data/obj/615e0c7f7afab83f.txt
#   inflating: data/obj/617d1c8ba7017f57.jpg
#   inflating: data/obj/617d1c8ba7017f57.txt
#   inflating: data/obj/61ca69f987b786a8.jpg
#   inflating: data/obj/61ca69f987b786a8.txt
#   inflating: data/obj/622270d1ca3a932a.jpg
#   inflating: data/obj/622270d1ca3a932a.txt
#   inflating: data/obj/6227f464c19f5af8.jpg
#   inflating: data/obj/6227f464c19f5af8.txt
#   inflating: data/obj/62384d7a34fe78fd.jpg
#   inflating: data/obj/62384d7a34fe78fd.txt
#   inflating: data/obj/625cbef12c306167.jpg
#   inflating: data/obj/625cbef12c306167.txt
#   inflating: data/obj/6284c5e12c6910d1.jpg
#   inflating: data/obj/6284c5e12c6910d1.txt
#   inflating: data/obj/633355c0106c0d1f.jpg
#   inflating: data/obj/633355c0106c0d1f.txt
#   inflating: data/obj/642d7ca1c9da79c4.jpg
#   inflating: data/obj/642d7ca1c9da79c4.txt
#   inflating: data/obj/64a4317276b5b443.jpg
#   inflating: data/obj/64a4317276b5b443.txt
#   inflating: data/obj/64a44253c90da141.jpg
#   inflating: data/obj/64a44253c90da141.txt
#   inflating: data/obj/6533c62178f3bf9f.jpg
#   inflating: data/obj/6533c62178f3bf9f.txt
#   inflating: data/obj/6598f6243bd477a7.jpg
#   inflating: data/obj/6598f6243bd477a7.txt
#   inflating: data/obj/65df172e3cd6c083.jpg
#   inflating: data/obj/65df172e3cd6c083.txt
#   inflating: data/obj/661025af030322ad.jpg
#   inflating: data/obj/661025af030322ad.txt
#   inflating: data/obj/66319432c247b93a.jpg
#   inflating: data/obj/66319432c247b93a.txt
#   inflating: data/obj/66f4baa96335c8a0.jpg
#   inflating: data/obj/66f4baa96335c8a0.txt
#   inflating: data/obj/6713196149cddade.jpg
#   inflating: data/obj/6713196149cddade.txt
#   inflating: data/obj/671589f35157e90b.jpg
#   inflating: data/obj/671589f35157e90b.txt
#   inflating: data/obj/6740254b4b0bcd05.jpg
#   inflating: data/obj/6740254b4b0bcd05.txt
#   inflating: data/obj/67ca3a4df6c5d15f.jpg
#   inflating: data/obj/67ca3a4df6c5d15f.txt
#   inflating: data/obj/682b662ed9f63fe4.jpg
#   inflating: data/obj/682b662ed9f63fe4.txt
#   inflating: data/obj/6a2938b38a60de1a.jpg
#   inflating: data/obj/6a2938b38a60de1a.txt
#   inflating: data/obj/6aa2f65452f9bdc2.jpg
#   inflating: data/obj/6aa2f65452f9bdc2.txt
#   inflating: data/obj/6add81e5d0aa566c.jpg
#   inflating: data/obj/6add81e5d0aa566c.txt
#   inflating: data/obj/6b53532e3974b38e.jpg
#   inflating: data/obj/6b53532e3974b38e.txt
#   inflating: data/obj/6b6f34cb206f5aa7.jpg
#   inflating: data/obj/6b6f34cb206f5aa7.txt
#   inflating: data/obj/6c30a514b9076ba8.jpg
#   inflating: data/obj/6c30a514b9076ba8.txt
#   inflating: data/obj/6c4eda32587964a4.jpg
#   inflating: data/obj/6c4eda32587964a4.txt
#   inflating: data/obj/6cb80449d9e0908b.jpg
#   inflating: data/obj/6cb80449d9e0908b.txt
#   inflating: data/obj/6d1fd4237b4aa41a.jpg
#   inflating: data/obj/6d1fd4237b4aa41a.txt
#   inflating: data/obj/6d3f835c948cbebc.jpg
#   inflating: data/obj/6d3f835c948cbebc.txt
#   inflating: data/obj/6da0febdb652c633.jpg
#   inflating: data/obj/6da0febdb652c633.txt
#   inflating: data/obj/6e2738df1bd10623.jpg
#   inflating: data/obj/6e2738df1bd10623.txt
#   inflating: data/obj/6f28c325657818b6.jpg
#   inflating: data/obj/6f28c325657818b6.txt
#   inflating: data/obj/6fa42a59d3a64396.jpg
#   inflating: data/obj/6fa42a59d3a64396.txt
#   inflating: data/obj/70eb26251b14c9cc.jpg
#   inflating: data/obj/70eb26251b14c9cc.txt
#   inflating: data/obj/711b7e17295f77ae.jpg
#   inflating: data/obj/711b7e17295f77ae.txt
#   inflating: data/obj/7135aa277e6404cd.jpg
#   inflating: data/obj/7135aa277e6404cd.txt
#   inflating: data/obj/718d0a04078c13ef.jpg
#   inflating: data/obj/718d0a04078c13ef.txt
#   inflating: data/obj/71f44e5fcf1913ea.jpg
#   inflating: data/obj/71f44e5fcf1913ea.txt
#   inflating: data/obj/7268989f91048d68.jpg
#   inflating: data/obj/7268989f91048d68.txt
#   inflating: data/obj/7308015839f79462.jpg
#   inflating: data/obj/7308015839f79462.txt
#   inflating: data/obj/731e666b635bf5f2.jpg
#   inflating: data/obj/731e666b635bf5f2.txt
#   inflating: data/obj/737a932553abea14.jpg
#   inflating: data/obj/737a932553abea14.txt
#   inflating: data/obj/73dc7122c2afc696.jpg
#   inflating: data/obj/73dc7122c2afc696.txt
#   inflating: data/obj/74381235d07b9e83.jpg
#   inflating: data/obj/74381235d07b9e83.txt
#   inflating: data/obj/743a0bbfd33cccc9.jpg
#   inflating: data/obj/743a0bbfd33cccc9.txt
#   inflating: data/obj/7485be5aea54e81a.jpg
#   inflating: data/obj/7485be5aea54e81a.txt
#   inflating: data/obj/7493b0390198bcb9.jpg
#   inflating: data/obj/7493b0390198bcb9.txt
#   inflating: data/obj/74ac044d1e1f4ff0.jpg
#   inflating: data/obj/74ac044d1e1f4ff0.txt
#   inflating: data/obj/751f6febc71b1ab2.jpg
#   inflating: data/obj/751f6febc71b1ab2.txt
#   inflating: data/obj/75ea914dfe63e65f.jpg
#   inflating: data/obj/75ea914dfe63e65f.txt
#   inflating: data/obj/7695cc6b98167c77.jpg
#   inflating: data/obj/7695cc6b98167c77.txt
#   inflating: data/obj/7729e42bac10c668.jpg
#   inflating: data/obj/7729e42bac10c668.txt
#   inflating: data/obj/7749ebc5b1f2e990.jpg
#   inflating: data/obj/7749ebc5b1f2e990.txt
#   inflating: data/obj/77d882334a598acc.jpg
#   inflating: data/obj/77d882334a598acc.txt
#   inflating: data/obj/77e910d1dd1a3e94.jpg
#   inflating: data/obj/77e910d1dd1a3e94.txt
#   inflating: data/obj/7853f24b40da431e.jpg
#   inflating: data/obj/7853f24b40da431e.txt
#   inflating: data/obj/790e74a101e14c3e.jpg
#   inflating: data/obj/790e74a101e14c3e.txt
#   inflating: data/obj/79c0cbf0caeb49e4.jpg
#   inflating: data/obj/79c0cbf0caeb49e4.txt
#   inflating: data/obj/7a3d9e46df224dc2.jpg
#   inflating: data/obj/7a3d9e46df224dc2.txt
#   inflating: data/obj/7a6b657952879f68.jpg
#   inflating: data/obj/7a6b657952879f68.txt
#   inflating: data/obj/7b1c9b4707b3f09d.jpg
#   inflating: data/obj/7b1c9b4707b3f09d.txt
#   inflating: data/obj/7bbbb4ed62789824.jpg
#   inflating: data/obj/7bbbb4ed62789824.txt
#   inflating: data/obj/7c9f0a321c40b9ec.jpg
#   inflating: data/obj/7c9f0a321c40b9ec.txt
#   inflating: data/obj/7d69a2fcbac1a80f.jpg
#   inflating: data/obj/7d69a2fcbac1a80f.txt
#   inflating: data/obj/7e346fd0f6c1bfaa.jpg
#   inflating: data/obj/7e346fd0f6c1bfaa.txt
#   inflating: data/obj/7f33d38f0fb240c4.jpg
#   inflating: data/obj/7f33d38f0fb240c4.txt
#   inflating: data/obj/80e5e532d466481a.jpg
#   inflating: data/obj/80e5e532d466481a.txt
#   inflating: data/obj/80f6db08669ff8e1.jpg
#   inflating: data/obj/80f6db08669ff8e1.txt
#   inflating: data/obj/816117d9687584e5.jpg
#   inflating: data/obj/816117d9687584e5.txt
#   inflating: data/obj/84b3ff523373c6b7.jpg
#   inflating: data/obj/84b3ff523373c6b7.txt
#   inflating: data/obj/84e60ead4e2eb49f.jpg
#   inflating: data/obj/84e60ead4e2eb49f.txt
#   inflating: data/obj/850682015fcb55bf.jpg
#   inflating: data/obj/850682015fcb55bf.txt
#   inflating: data/obj/856746ed584fa880.jpg
#   inflating: data/obj/856746ed584fa880.txt
#   inflating: data/obj/857936433707d95b.jpg
#   inflating: data/obj/857936433707d95b.txt
#   inflating: data/obj/85988adf125684b0.jpg
#   inflating: data/obj/85988adf125684b0.txt
#   inflating: data/obj/8635ada56b2e4fa2.jpg
#   inflating: data/obj/8635ada56b2e4fa2.txt
#   inflating: data/obj/86814c4b22ea717e.jpg
#   inflating: data/obj/86814c4b22ea717e.txt
#   inflating: data/obj/86dcf6dc51d08772.jpg
#   inflating: data/obj/86dcf6dc51d08772.txt
#   inflating: data/obj/8703056920325957.jpg
#   inflating: data/obj/8703056920325957.txt
#   inflating: data/obj/8732e88a1ea45201.jpg
#   inflating: data/obj/8732e88a1ea45201.txt
#   inflating: data/obj/88043362d2365eb6.jpg
#   inflating: data/obj/88043362d2365eb6.txt
#   inflating: data/obj/8808d73076430a66.jpg
#   inflating: data/obj/8808d73076430a66.txt
#   inflating: data/obj/88586fa932a0db90.jpg
#   inflating: data/obj/88586fa932a0db90.txt
#   inflating: data/obj/88726d2398ab6a06.jpg
#   inflating: data/obj/88726d2398ab6a06.txt
#   inflating: data/obj/8a83ac8e3610cb0d.jpg
#   inflating: data/obj/8a83ac8e3610cb0d.txt
#   inflating: data/obj/8d6d5574d5c97d5c.jpg
#   inflating: data/obj/8d6d5574d5c97d5c.txt
#   inflating: data/obj/8d7cd7adc9410ef9.jpg
#   inflating: data/obj/8d7cd7adc9410ef9.txt
#   inflating: data/obj/8e1ffd927774d53e.jpg
#   inflating: data/obj/8e1ffd927774d53e.txt
#   inflating: data/obj/8e96761a6e4eee9d.jpg
#   inflating: data/obj/8e96761a6e4eee9d.txt
#   inflating: data/obj/8ec6f9ff27ab0b57.jpg
#   inflating: data/obj/8ec6f9ff27ab0b57.txt
#   inflating: data/obj/8f674f96f867449a.jpg
#   inflating: data/obj/8f674f96f867449a.txt
#   inflating: data/obj/8fcc419880d6d3a0.jpg
#   inflating: data/obj/8fcc419880d6d3a0.txt
#   inflating: data/obj/8fd4a85db63db48e.jpg
#   inflating: data/obj/8fd4a85db63db48e.txt
#   inflating: data/obj/8fdf4f82f64d334c.jpg
#   inflating: data/obj/8fdf4f82f64d334c.txt
#   inflating: data/obj/907eb7f640bde6b9.jpg
#   inflating: data/obj/907eb7f640bde6b9.txt
#   inflating: data/obj/90fd7e03598eb734.jpg
#   inflating: data/obj/90fd7e03598eb734.txt
#   inflating: data/obj/912b1423f837ac72.jpg
#   inflating: data/obj/912b1423f837ac72.txt
#   inflating: data/obj/921398e85ea3786e.jpg
#   inflating: data/obj/921398e85ea3786e.txt
#   inflating: data/obj/9230e9383bf7c364.jpg
#   inflating: data/obj/9230e9383bf7c364.txt
#   inflating: data/obj/9264eef4f626fc22.jpg
#   inflating: data/obj/9264eef4f626fc22.txt
#   inflating: data/obj/93ba6f3907af1be1.jpg
#   inflating: data/obj/93ba6f3907af1be1.txt
#   inflating: data/obj/946a2f5450a71a13.jpg
#   inflating: data/obj/946a2f5450a71a13.txt
#   inflating: data/obj/9493f130a3fe4389.jpg
#   inflating: data/obj/9493f130a3fe4389.txt
#   inflating: data/obj/950fd246448184c7.jpg
#   inflating: data/obj/950fd246448184c7.txt
#   inflating: data/obj/951836c90c23a6ac.jpg
#   inflating: data/obj/951836c90c23a6ac.txt
#   inflating: data/obj/955f885b36f5db79.jpg
#   inflating: data/obj/955f885b36f5db79.txt
#   inflating: data/obj/96ae4857d6f9bf8a.jpg
#   inflating: data/obj/96ae4857d6f9bf8a.txt
#   inflating: data/obj/96db0ab349f62f09.jpg
#   inflating: data/obj/96db0ab349f62f09.txt
#   inflating: data/obj/976a4388907b028a.jpg
#   inflating: data/obj/976a4388907b028a.txt
#   inflating: data/obj/97c4d263982b00a2.jpg
#   inflating: data/obj/97c4d263982b00a2.txt
#   inflating: data/obj/97c85829671d86bd.jpg
#   inflating: data/obj/97c85829671d86bd.txt
#   inflating: data/obj/97c8ef056ee99d5d.jpg
#   inflating: data/obj/97c8ef056ee99d5d.txt
#   inflating: data/obj/9810a35da09c34ba.jpg
#   inflating: data/obj/9810a35da09c34ba.txt
#   inflating: data/obj/989c65381a64eb5c.jpg
#   inflating: data/obj/989c65381a64eb5c.txt
#   inflating: data/obj/99186db78ad7d1b9.jpg
#   inflating: data/obj/99186db78ad7d1b9.txt
#   inflating: data/obj/99ac9754b8981eeb.jpg
#   inflating: data/obj/99ac9754b8981eeb.txt
#   inflating: data/obj/9b72cae9ecbb8d93.jpg
#   inflating: data/obj/9b72cae9ecbb8d93.txt
#   inflating: data/obj/9b7c1256b0adf962.jpg
#   inflating: data/obj/9b7c1256b0adf962.txt
#   inflating: data/obj/9b86503b3c80126b.jpg
#   inflating: data/obj/9b86503b3c80126b.txt
#   inflating: data/obj/9c28d9fbd6f174e8.jpg
#   inflating: data/obj/9c28d9fbd6f174e8.txt
#   inflating: data/obj/9c579b190679d1d7.jpg
#   inflating: data/obj/9c579b190679d1d7.txt
#   inflating: data/obj/9d776d3133065e25.jpg
#   inflating: data/obj/9d776d3133065e25.txt
#   inflating: data/obj/9d8b97a50330a6e0.jpg
#   inflating: data/obj/9d8b97a50330a6e0.txt
#   inflating: data/obj/9daf7c2cd2fe89f4.jpg
#   inflating: data/obj/9daf7c2cd2fe89f4.txt
#   inflating: data/obj/9e90681792de9715.jpg
#   inflating: data/obj/9e90681792de9715.txt
#   inflating: data/obj/9f11445d2fee19ea.jpg
#   inflating: data/obj/9f11445d2fee19ea.txt
#   inflating: data/obj/9fd58bd27859c12c.jpg
#   inflating: data/obj/9fd58bd27859c12c.txt
#   inflating: data/obj/a165cda6034e2ca9.jpg
#   inflating: data/obj/a165cda6034e2ca9.txt
#   inflating: data/obj/a2297c2631b9046c.jpg
#   inflating: data/obj/a2297c2631b9046c.txt
#   inflating: data/obj/a24b02155c339ecc.jpg
#   inflating: data/obj/a24b02155c339ecc.txt
#   inflating: data/obj/a2bbf9bb9586b91c.jpg
#   inflating: data/obj/a2bbf9bb9586b91c.txt
#   inflating: data/obj/a306aba55f25c426.jpg
#   inflating: data/obj/a306aba55f25c426.txt
#   inflating: data/obj/a31da5959ed7a655.jpg
#   inflating: data/obj/a31da5959ed7a655.txt
#   inflating: data/obj/a416e2b34e939e51.jpg
#   inflating: data/obj/a416e2b34e939e51.txt
#   inflating: data/obj/a45a72d3115d4fd0.jpg
#   inflating: data/obj/a45a72d3115d4fd0.txt
#   inflating: data/obj/a530989bb80724b0.jpg
#   inflating: data/obj/a530989bb80724b0.txt
#   inflating: data/obj/a57fffda6b80ea4c.jpg
#   inflating: data/obj/a57fffda6b80ea4c.txt
#   inflating: data/obj/a589d451fc9bcfb6.jpg
#   inflating: data/obj/a589d451fc9bcfb6.txt
#   inflating: data/obj/a5be245e4f051629.jpg
#   inflating: data/obj/a5be245e4f051629.txt
#   inflating: data/obj/a5d4addc962eb412.jpg
#   inflating: data/obj/a5d4addc962eb412.txt
#   inflating: data/obj/a5fd6c27f8d7006f.jpg
#   inflating: data/obj/a5fd6c27f8d7006f.txt
#   inflating: data/obj/a6bd0e2e168fd3b5.jpg
#   inflating: data/obj/a6bd0e2e168fd3b5.txt
#   inflating: data/obj/a732affcd26abe99.jpg
#   inflating: data/obj/a732affcd26abe99.txt
#   inflating: data/obj/a7b060f21d1f21e5.jpg
#   inflating: data/obj/a7b060f21d1f21e5.txt
#   inflating: data/obj/a87e4519bb673e7b.jpg
#   inflating: data/obj/a87e4519bb673e7b.txt
#   inflating: data/obj/a89c8d46ade4894b.jpg
#   inflating: data/obj/a89c8d46ade4894b.txt
#   inflating: data/obj/a8ffdccc5ba8082c.jpg
#   inflating: data/obj/a8ffdccc5ba8082c.txt
#   inflating: data/obj/a9285906a1c8ae67.jpg
#   inflating: data/obj/a9285906a1c8ae67.txt
#   inflating: data/obj/a9661b9012306019.jpg
#   inflating: data/obj/a9661b9012306019.txt
#   inflating: data/obj/a9e33dfdba071bf7.jpg
#   inflating: data/obj/a9e33dfdba071bf7.txt
#   inflating: data/obj/ab408f0290a8b713.jpg
#   inflating: data/obj/ab408f0290a8b713.txt
#   inflating: data/obj/abbe45011a74e09b.jpg
#   inflating: data/obj/abbe45011a74e09b.txt
#   inflating: data/obj/ac003c1a38c0e4e8.jpg
#   inflating: data/obj/ac003c1a38c0e4e8.txt
#   inflating: data/obj/ac59f88e944dfce2.jpg
#   inflating: data/obj/ac59f88e944dfce2.txt
#   inflating: data/obj/ac8fd2d7ba9a006d.jpg
#   inflating: data/obj/ac8fd2d7ba9a006d.txt
#   inflating: data/obj/acca13852b3ed1c3.jpg
#   inflating: data/obj/acca13852b3ed1c3.txt
#   inflating: data/obj/acde9677555bedb7.jpg
#   inflating: data/obj/acde9677555bedb7.txt
#   inflating: data/obj/adb37cd5456db58c.jpg
#   inflating: data/obj/adb37cd5456db58c.txt
#   inflating: data/obj/ade97394b320db73.jpg
#   inflating: data/obj/ade97394b320db73.txt
#   inflating: data/obj/ae128254f35a0d99.jpg
#   inflating: data/obj/ae128254f35a0d99.txt
#   inflating: data/obj/ae1a19be26374625.jpg
#   inflating: data/obj/ae1a19be26374625.txt
#   inflating: data/obj/ae4b404758bc2789.jpg
#   inflating: data/obj/ae4b404758bc2789.txt
#   inflating: data/obj/ae9d6b97bcb35fda.jpg
#   inflating: data/obj/ae9d6b97bcb35fda.txt
#   inflating: data/obj/aec13c1b4ad59873.jpg
#   inflating: data/obj/aec13c1b4ad59873.txt
#   inflating: data/obj/af20d5f291d0ff23.jpg
#   inflating: data/obj/af20d5f291d0ff23.txt
#   inflating: data/obj/b02501ab4db4abca.jpg
#   inflating: data/obj/b02501ab4db4abca.txt
#   inflating: data/obj/b0307ddf7a830b34.jpg
#   inflating: data/obj/b0307ddf7a830b34.txt
#   inflating: data/obj/b06c8e0565d5c5a9.jpg
#   inflating: data/obj/b06c8e0565d5c5a9.txt
#   inflating: data/obj/b111a303a715c18a.jpg
#   inflating: data/obj/b111a303a715c18a.txt
#   inflating: data/obj/b1278b84ca4b1502.jpg
#   inflating: data/obj/b1278b84ca4b1502.txt
#   inflating: data/obj/b1a69cf7e06144a5.jpg
#   inflating: data/obj/b1a69cf7e06144a5.txt
#   inflating: data/obj/b1e1b068a62f6380.jpg
#   inflating: data/obj/b1e1b068a62f6380.txt
#   inflating: data/obj/b27bbdab814ff244.jpg
#   inflating: data/obj/b27bbdab814ff244.txt
#   inflating: data/obj/b29c2ac22b3bafda.jpg
#   inflating: data/obj/b29c2ac22b3bafda.txt
#   inflating: data/obj/b2f7519b0090a5ca.jpg
#   inflating: data/obj/b2f7519b0090a5ca.txt
#   inflating: data/obj/b2f9a0590394beca.jpg
#   inflating: data/obj/b2f9a0590394beca.txt
#   inflating: data/obj/b32a14ae18106559.jpg
#   inflating: data/obj/b32a14ae18106559.txt
#   inflating: data/obj/b3880a68265ec2fb.jpg
#   inflating: data/obj/b3880a68265ec2fb.txt
#   inflating: data/obj/b3cf25647390d090.jpg
#   inflating: data/obj/b3cf25647390d090.txt
#   inflating: data/obj/b3e5df83a6221808.jpg
#   inflating: data/obj/b3e5df83a6221808.txt
#   inflating: data/obj/b40a2744c514903c.jpg
#   inflating: data/obj/b40a2744c514903c.txt
#   inflating: data/obj/b4f2d91a164bc3ef.jpg
#   inflating: data/obj/b4f2d91a164bc3ef.txt
#   inflating: data/obj/b514b8302f35ba30.jpg
#   inflating: data/obj/b514b8302f35ba30.txt
#   inflating: data/obj/b52f3e526ac3b098.jpg
#   inflating: data/obj/b52f3e526ac3b098.txt
#   inflating: data/obj/b5e98f0c653b9892.jpg
#   inflating: data/obj/b5e98f0c653b9892.txt
#   inflating: data/obj/b6503552552bd24a.jpg
#   inflating: data/obj/b6503552552bd24a.txt
#   inflating: data/obj/b65d530bc6703dbf.jpg
#   inflating: data/obj/b65d530bc6703dbf.txt
#   inflating: data/obj/b6c5568bc237aa66.jpg
#   inflating: data/obj/b6c5568bc237aa66.txt
#   inflating: data/obj/b73e8d0676a65951.jpg
#   inflating: data/obj/b73e8d0676a65951.txt
#   inflating: data/obj/b77a8d56343560fa.jpg
#   inflating: data/obj/b77a8d56343560fa.txt
#   inflating: data/obj/b7b8016bba53e976.jpg
#   inflating: data/obj/b7b8016bba53e976.txt
#   inflating: data/obj/b80a3269856e0836.jpg
#   inflating: data/obj/b80a3269856e0836.txt
#   inflating: data/obj/b8da2d5377edbac8.jpg
#   inflating: data/obj/b8da2d5377edbac8.txt
#   inflating: data/obj/b8e75791c5bb4415.jpg
#   inflating: data/obj/b8e75791c5bb4415.txt
#   inflating: data/obj/b9251dd87ad39ccf.jpg
#   inflating: data/obj/b9251dd87ad39ccf.txt
#   inflating: data/obj/b9b7da6597134d41.jpg
#   inflating: data/obj/b9b7da6597134d41.txt
#   inflating: data/obj/b9bfdc0d28b94a3e.jpg
#   inflating: data/obj/b9bfdc0d28b94a3e.txt
#   inflating: data/obj/b9d3175b749c519f.jpg
#   inflating: data/obj/b9d3175b749c519f.txt
#   inflating: data/obj/b9fd61b70c4d9c51.jpg
#   inflating: data/obj/b9fd61b70c4d9c51.txt
#   inflating: data/obj/ba83027cefcadb0d.jpg
#   inflating: data/obj/ba83027cefcadb0d.txt
#   inflating: data/obj/bc9b4f4a34987624.jpg
#   inflating: data/obj/bc9b4f4a34987624.txt
#   inflating: data/obj/bd09a59f168aabd6.jpg
#   inflating: data/obj/bd09a59f168aabd6.txt
#   inflating: data/obj/be066df281d5f634.jpg
#   inflating: data/obj/be066df281d5f634.txt
#   inflating: data/obj/be43d7d6753c85c7.jpg
#   inflating: data/obj/be43d7d6753c85c7.txt
#   inflating: data/obj/bfa696cb7ca1afae.jpg
#   inflating: data/obj/bfa696cb7ca1afae.txt
#   inflating: data/obj/bfdfc18f2694f6a0.jpg
#   inflating: data/obj/bfdfc18f2694f6a0.txt
#   inflating: data/obj/bffc78ee896ea064.jpg
#   inflating: data/obj/bffc78ee896ea064.txt
#   inflating: data/obj/c022f3642a6fd807.jpg
#   inflating: data/obj/c022f3642a6fd807.txt
#   inflating: data/obj/c02aeebe5a7f4b9b.jpg
#   inflating: data/obj/c02aeebe5a7f4b9b.txt
#   inflating: data/obj/c13c3726fc896fba.jpg
#   inflating: data/obj/c13c3726fc896fba.txt
#   inflating: data/obj/c1ce712e50d1e9f2.jpg
#   inflating: data/obj/c1ce712e50d1e9f2.txt
#   inflating: data/obj/c59f5e2e2bc90645.jpg
#   inflating: data/obj/c59f5e2e2bc90645.txt
#   inflating: data/obj/c5aad264d5830ab2.jpg
#   inflating: data/obj/c5aad264d5830ab2.txt
#   inflating: data/obj/c628492b4b5a8061.jpg
#   inflating: data/obj/c628492b4b5a8061.txt
#   inflating: data/obj/c6c2305ab5107409.jpg
#   inflating: data/obj/c6c2305ab5107409.txt
#   inflating: data/obj/c71307359ee6f94d.jpg
#   inflating: data/obj/c71307359ee6f94d.txt
#   inflating: data/obj/c7ab4570907f6081.jpg
#   inflating: data/obj/c7ab4570907f6081.txt
#   inflating: data/obj/c7e9264ba9a6225d.jpg
#   inflating: data/obj/c7e9264ba9a6225d.txt
#   inflating: data/obj/c91f90817c404a1d.jpg
#   inflating: data/obj/c91f90817c404a1d.txt
#   inflating: data/obj/c987cf49c205dcf4.jpg
#   inflating: data/obj/c987cf49c205dcf4.txt
#   inflating: data/obj/c9a99643e9ee08f2.jpg
#   inflating: data/obj/c9a99643e9ee08f2.txt
#   inflating: data/obj/c9b7d70d1b8235c8.jpg
#   inflating: data/obj/c9b7d70d1b8235c8.txt
#   inflating: data/obj/c9e3d8099cd9b2ae.jpg
#   inflating: data/obj/c9e3d8099cd9b2ae.txt
#   inflating: data/obj/c9ef1ad6092d5059.jpg
#   inflating: data/obj/c9ef1ad6092d5059.txt
#   inflating: data/obj/ca27d843ede1ab8d.jpg
#   inflating: data/obj/ca27d843ede1ab8d.txt
#   inflating: data/obj/ca3da422de541882.jpg
#   inflating: data/obj/ca3da422de541882.txt
#   inflating: data/obj/cad8b2938fe85125.jpg
#   inflating: data/obj/cad8b2938fe85125.txt
#   inflating: data/obj/cad9ac62665cb87d.jpg
#   inflating: data/obj/cad9ac62665cb87d.txt
#   inflating: data/obj/cb09c8c5d716169e.jpg
#   inflating: data/obj/cb09c8c5d716169e.txt
#   inflating: data/obj/cba13ae154be39e8.jpg
#   inflating: data/obj/cba13ae154be39e8.txt
#   inflating: data/obj/cbec8a8c9b4a3679.jpg
#   inflating: data/obj/cbec8a8c9b4a3679.txt
#   inflating: data/obj/cc3d7662ee8de657.jpg
#   inflating: data/obj/cc3d7662ee8de657.txt
#   inflating: data/obj/ccecbc90c26e06ae.jpg
#   inflating: data/obj/ccecbc90c26e06ae.txt
#   inflating: data/obj/cd6771b7011ab171.jpg
#   inflating: data/obj/cd6771b7011ab171.txt
#   inflating: data/obj/cd73cff23bd04965.jpg
#   inflating: data/obj/cd73cff23bd04965.txt
#   inflating: data/obj/ce58cf595d82cd35.jpg
#   inflating: data/obj/ce58cf595d82cd35.txt
#   inflating: data/obj/ce5e8c2fdaeda620.jpg
#   inflating: data/obj/ce5e8c2fdaeda620.txt
#   inflating: data/obj/cf11129528f188f7.jpg
#   inflating: data/obj/cf11129528f188f7.txt
#   inflating: data/obj/cf392f50d9bbe260.jpg
#   inflating: data/obj/cf392f50d9bbe260.txt
#   inflating: data/obj/cfa998c879fb2b07.jpg
#   inflating: data/obj/cfa998c879fb2b07.txt
#   inflating: data/obj/d088bea53fa7db39.jpg
#   inflating: data/obj/d088bea53fa7db39.txt
#   inflating: data/obj/d0fa879bc59bfb32.jpg
#   inflating: data/obj/d0fa879bc59bfb32.txt
#   inflating: data/obj/d10b9f50ec267ca0.jpg
#   inflating: data/obj/d10b9f50ec267ca0.txt
#   inflating: data/obj/d1267f958e449d69.jpg
#   inflating: data/obj/d1267f958e449d69.txt
#   inflating: data/obj/d16cd31ae773e814.jpg
#   inflating: data/obj/d16cd31ae773e814.txt
#   inflating: data/obj/d1c56297e5045248.jpg
#   inflating: data/obj/d1c56297e5045248.txt
#   inflating: data/obj/d1fb5dd0a913d354.jpg
#   inflating: data/obj/d1fb5dd0a913d354.txt
#   inflating: data/obj/d29fe4063768b7ba.jpg
#   inflating: data/obj/d29fe4063768b7ba.txt
#   inflating: data/obj/d2c1eb8cd69338e8.jpg
#   inflating: data/obj/d2c1eb8cd69338e8.txt
#   inflating: data/obj/d38e462a23434bcc.jpg
#   inflating: data/obj/d38e462a23434bcc.txt
#   inflating: data/obj/d3cee7afa3f58057.jpg
#   inflating: data/obj/d3cee7afa3f58057.txt
#   inflating: data/obj/d48d0028123c9af5.jpg
#   inflating: data/obj/d48d0028123c9af5.txt
#   inflating: data/obj/d4b9ac9d9e0010fe.jpg
#   inflating: data/obj/d4b9ac9d9e0010fe.txt
#   inflating: data/obj/d4ed8bb4bef6bcc6.jpg
#   inflating: data/obj/d4ed8bb4bef6bcc6.txt
#   inflating: data/obj/d55ba317ca0a06bb.jpg
#   inflating: data/obj/d55ba317ca0a06bb.txt
#   inflating: data/obj/d5674f2c512a2ac6.jpg
#   inflating: data/obj/d5674f2c512a2ac6.txt
#   inflating: data/obj/d6408009ac7beb96.jpg
#   inflating: data/obj/d6408009ac7beb96.txt
#   inflating: data/obj/d76446d0dc755d68.jpg
#   inflating: data/obj/d76446d0dc755d68.txt
#   inflating: data/obj/d7ab4fa462cde266.jpg
#   inflating: data/obj/d7ab4fa462cde266.txt
#   inflating: data/obj/d7cb4ac33003492c.jpg
#   inflating: data/obj/d7cb4ac33003492c.txt
#   inflating: data/obj/d7d39350391fd4fb.jpg
#   inflating: data/obj/d7d39350391fd4fb.txt
#   inflating: data/obj/d83724b61ddc2716.jpg
#   inflating: data/obj/d83724b61ddc2716.txt
#   inflating: data/obj/d85c00ad7c3f86f2.jpg
#   inflating: data/obj/d85c00ad7c3f86f2.txt
#   inflating: data/obj/d8b264046ead6435.jpg
#   inflating: data/obj/d8b264046ead6435.txt
#   inflating: data/obj/d8f8b0dcce9481ef.jpg
#   inflating: data/obj/d8f8b0dcce9481ef.txt
#   inflating: data/obj/d9ced04add06399c.jpg
#   inflating: data/obj/d9ced04add06399c.txt
#   inflating: data/obj/da4f0a1eaabb81bb.jpg
#   inflating: data/obj/da4f0a1eaabb81bb.txt
#   inflating: data/obj/dac29ed8400b50cc.jpg
#   inflating: data/obj/dac29ed8400b50cc.txt
#   inflating: data/obj/db6a7948eae2b30d.jpg
#   inflating: data/obj/db6a7948eae2b30d.txt
#   inflating: data/obj/db6e203645358a41.jpg
#   inflating: data/obj/db6e203645358a41.txt
#   inflating: data/obj/dc5d88b0925c24d0.jpg
#   inflating: data/obj/dc5d88b0925c24d0.txt
#   inflating: data/obj/dcb7e54fd2557df2.jpg
#   inflating: data/obj/dcb7e54fd2557df2.txt
#   inflating: data/obj/dcd4ec35862c8a8f.jpg
#   inflating: data/obj/dcd4ec35862c8a8f.txt
#   inflating: data/obj/dcd9070f8f0bc84a.jpg
#   inflating: data/obj/dcd9070f8f0bc84a.txt
#   inflating: data/obj/dd1d11fb4171188f.jpg
#   inflating: data/obj/dd1d11fb4171188f.txt
#   inflating: data/obj/dd86755d2cdc0b9b.jpg
#   inflating: data/obj/dd86755d2cdc0b9b.txt
#   inflating: data/obj/de27472872d7a815.jpg
#   inflating: data/obj/de27472872d7a815.txt
#   inflating: data/obj/de9ca35f9736a54e.jpg
#   inflating: data/obj/de9ca35f9736a54e.txt
#   inflating: data/obj/df90f0452f53510c.jpg
#   inflating: data/obj/df90f0452f53510c.txt
#   inflating: data/obj/dfd6283d8d32ed46.jpg
#   inflating: data/obj/dfd6283d8d32ed46.txt
#   inflating: data/obj/dfedd2bd7b132ac5.jpg
#   inflating: data/obj/dfedd2bd7b132ac5.txt
#   inflating: data/obj/e077b6facf72bf1e.jpg
#   inflating: data/obj/e077b6facf72bf1e.txt
#   inflating: data/obj/e115dfe21ba21c75.jpg
#   inflating: data/obj/e115dfe21ba21c75.txt
#   inflating: data/obj/e16d33356d0c9be6.jpg
#   inflating: data/obj/e16d33356d0c9be6.txt
#   inflating: data/obj/e18045f01a620ad1.jpg
#   inflating: data/obj/e18045f01a620ad1.txt
#   inflating: data/obj/e1dc69e098b3e278.jpg
#   inflating: data/obj/e1dc69e098b3e278.txt
#   inflating: data/obj/e1e69e132104a2d1.jpg
#   inflating: data/obj/e1e69e132104a2d1.txt
#   inflating: data/obj/e24d8347089c0c8a.jpg
#   inflating: data/obj/e24d8347089c0c8a.txt
#   inflating: data/obj/e36ddb8f2e38ac21.jpg
#   inflating: data/obj/e36ddb8f2e38ac21.txt
#   inflating: data/obj/e39361bc966cdf0d.jpg
#   inflating: data/obj/e39361bc966cdf0d.txt
#   inflating: data/obj/e568c1a5fdc9f81d.jpg
#   inflating: data/obj/e568c1a5fdc9f81d.txt
#   inflating: data/obj/e59c783aa8e487b4.jpg
#   inflating: data/obj/e59c783aa8e487b4.txt
#   inflating: data/obj/e5b76f031e041e90.jpg
#   inflating: data/obj/e5b76f031e041e90.txt
#   inflating: data/obj/e68ce172f541f7b0.jpg
#   inflating: data/obj/e68ce172f541f7b0.txt
#   inflating: data/obj/e6ed99279868f6fc.jpg
#   inflating: data/obj/e6ed99279868f6fc.txt
#   inflating: data/obj/e8aa53b573edc2e7.jpg
#   inflating: data/obj/e8aa53b573edc2e7.txt
#   inflating: data/obj/e938bcdcf8245bf8.jpg
#   inflating: data/obj/e938bcdcf8245bf8.txt
#   inflating: data/obj/e941ef5fb248999c.jpg
#   inflating: data/obj/e941ef5fb248999c.txt
#   inflating: data/obj/e9af0ddfc5fa5020.jpg
#   inflating: data/obj/e9af0ddfc5fa5020.txt
#   inflating: data/obj/ea131bb32ce30682.jpg
#   inflating: data/obj/ea131bb32ce30682.txt
#   inflating: data/obj/eb2f1203508a74fb.jpg
#   inflating: data/obj/eb2f1203508a74fb.txt
#   inflating: data/obj/ebc059893848b3be.jpg
#   inflating: data/obj/ebc059893848b3be.txt
#   inflating: data/obj/ec2f731c2e2eb9c3.jpg
#   inflating: data/obj/ec2f731c2e2eb9c3.txt
#   inflating: data/obj/ec3b9672c9c86512.jpg
#   inflating: data/obj/ec3b9672c9c86512.txt
#   inflating: data/obj/eca2a966528d669b.jpg
#   inflating: data/obj/eca2a966528d669b.txt
#   inflating: data/obj/ecb66cf8aaee88f9.jpg
#   inflating: data/obj/ecb66cf8aaee88f9.txt
#   inflating: data/obj/ecee91193898df3c.jpg
#   inflating: data/obj/ecee91193898df3c.txt
#   inflating: data/obj/ed5f51a4e77809c9.jpg
#   inflating: data/obj/ed5f51a4e77809c9.txt
#   inflating: data/obj/eda0007689c60ba1.jpg
#   inflating: data/obj/eda0007689c60ba1.txt
#   inflating: data/obj/ee11f0a07dc8de70.jpg
#   inflating: data/obj/ee11f0a07dc8de70.txt
#   inflating: data/obj/ee5935170dc52788.jpg
#   inflating: data/obj/ee5935170dc52788.txt
#   inflating: data/obj/eec4ba78c9b8f7cf.jpg
#   inflating: data/obj/eec4ba78c9b8f7cf.txt
#   inflating: data/obj/ef37e1ba761b1313.jpg
#   inflating: data/obj/ef37e1ba761b1313.txt
#   inflating: data/obj/ef530e18d073dfe5.jpg
#   inflating: data/obj/ef530e18d073dfe5.txt
#   inflating: data/obj/ef5f54370892a7b6.jpg
#   inflating: data/obj/ef5f54370892a7b6.txt
#   inflating: data/obj/ef936296c579a83f.jpg
#   inflating: data/obj/ef936296c579a83f.txt
#   inflating: data/obj/ef9d606070adcc38.jpg
#   inflating: data/obj/ef9d606070adcc38.txt
#   inflating: data/obj/efc171546053cecc.jpg
#   inflating: data/obj/efc171546053cecc.txt
#   inflating: data/obj/f011ed94e450c417.jpg
#   inflating: data/obj/f011ed94e450c417.txt
#   inflating: data/obj/f02139c77b7554ef.jpg
#   inflating: data/obj/f02139c77b7554ef.txt
#   inflating: data/obj/f13667f60e052402.jpg
#   inflating: data/obj/f13667f60e052402.txt
#   inflating: data/obj/f18432fb0602658d.jpg
#   inflating: data/obj/f18432fb0602658d.txt
#   inflating: data/obj/f187627780b23380.jpg
#   inflating: data/obj/f187627780b23380.txt
#   inflating: data/obj/f21cc3311097aefa.jpg
#   inflating: data/obj/f21cc3311097aefa.txt
#   inflating: data/obj/f2adb2503d120e14.jpg
#   inflating: data/obj/f2adb2503d120e14.txt
#   inflating: data/obj/f2b9d0eaa33d3d0f.jpg
#   inflating: data/obj/f2b9d0eaa33d3d0f.txt
#   inflating: data/obj/f3f7506851462b2c.jpg
#   inflating: data/obj/f3f7506851462b2c.txt
#   inflating: data/obj/f3fd2a5caa6c0c87.jpg
#   inflating: data/obj/f3fd2a5caa6c0c87.txt
#   inflating: data/obj/f492fc50c6501099.jpg
#   inflating: data/obj/f492fc50c6501099.txt
#   inflating: data/obj/f6042a807d9160dc.jpg
#   inflating: data/obj/f6042a807d9160dc.txt
#   inflating: data/obj/f6735981a3563205.jpg
#   inflating: data/obj/f6735981a3563205.txt
#   inflating: data/obj/f6d92ff97355515c.jpg
#   inflating: data/obj/f6d92ff97355515c.txt
#   inflating: data/obj/f6fe2cec5d78a1b3.jpg
#   inflating: data/obj/f6fe2cec5d78a1b3.txt
#   inflating: data/obj/f70a27725c68a6ba.jpg
#   inflating: data/obj/f70a27725c68a6ba.txt
#   inflating: data/obj/f7401f63b03af92b.jpg
#   inflating: data/obj/f7401f63b03af92b.txt
#   inflating: data/obj/f75920a2a33fd66c.jpg
#   inflating: data/obj/f75920a2a33fd66c.txt
#   inflating: data/obj/f7778d150ff49a5b.jpg
#   inflating: data/obj/f7778d150ff49a5b.txt
#   inflating: data/obj/f80d5544d37219ca.jpg
#   inflating: data/obj/f80d5544d37219ca.txt
#   inflating: data/obj/f9d431d6283ac4d4.jpg
#   inflating: data/obj/f9d431d6283ac4d4.txt
#   inflating: data/obj/f9e2abc424e18727.jpg
#   inflating: data/obj/f9e2abc424e18727.txt
#   inflating: data/obj/fa7f63a6f238a387.jpg
#   inflating: data/obj/fa7f63a6f238a387.txt
#   inflating: data/obj/fabd56048f5d4289.jpg
#   inflating: data/obj/fabd56048f5d4289.txt
#   inflating: data/obj/fb9d17c6f2ef2b69.jpg
#   inflating: data/obj/fb9d17c6f2ef2b69.txt
#   inflating: data/obj/fbf198cee5f3b934.jpg
#   inflating: data/obj/fbf198cee5f3b934.txt
#   inflating: data/obj/fcb000d0be4ed0d7.jpg
#   inflating: data/obj/fcb000d0be4ed0d7.txt
#   inflating: data/obj/fceb23e4129b430c.jpg
#   inflating: data/obj/fceb23e4129b430c.txt
#   inflating: data/obj/fd3ffb5f5977ca44.jpg
#   inflating: data/obj/fd3ffb5f5977ca44.txt
#   inflating: data/obj/fd4e82df7ad4f21e.jpg
#   inflating: data/obj/fd4e82df7ad4f21e.txt
#   inflating: data/obj/fd9ba30a36fea6f9.jpg
#   inflating: data/obj/fd9ba30a36fea6f9.txt
#   inflating: data/obj/fde0ffb64e91e67e.jpg
#   inflating: data/obj/fde0ffb64e91e67e.txt
#   inflating: data/obj/fe6c34e388acb106.jpg
#   inflating: data/obj/fe6c34e388acb106.txt
#   inflating: data/obj/fed541b987bba40c.jpg
#   inflating: data/obj/fed541b987bba40c.txt
#   inflating: data/obj/feda55eb375dd457.jpg
#   inflating: data/obj/feda55eb375dd457.txt
#   inflating: data/obj/ffaa77b43b2b5c5d.jpg
#   inflating: data/obj/ffaa77b43b2b5c5d.txt

# %% [markdown]
# # Step 3: 학습할 수 있도록 파일들의 설정을 바꾸기
#
# .cfg 파일, obj.data, obj.names, train.txt 파일들에 대해 설정을 바꾸기
#
#
# 다음 유튜브에는 파일들의 설정을 바꾸는 방법이 잘 설명되어 있다 [Configuring YOLOv3 Files for Training](https://www.youtube.com/watch?v=zJDUhGL26iU&t=300s)
#
# ## i) Cfg 파일
# 먼저 yolov3.cfg 를 copy하고 편집하기

# %%
# cfg파일을 구글 드라이브로 복사하고 이름을 바꾸기
# !cp cfg/yolov3.cfg /mydrive/yolov3/yolov3_custom.cfg

# %%
# PC로 다운로드하려면 다음과 같이 하면 된다. 다운로드후에는 파일 이름을 yolov3_custom.cfg로 바꾸면 된다.
download('cfg/yolov3.cfg')

# %% [markdown]
# 이제 편집기를 이용하여 .cfg파일을 편집하면 된다.
#
# yolov3_custom.cfg파일 구글 드라이브에 있다면 파일을 더블클릭한 후에 **Open with** 드롭다운에서  **Text Editor**를 선택하면 된다.
# ![image.png](data:image/png;base64,...)
#
# 추천:  **batch = 64** 와 **subdivisions = 16** 로 놓는 것을 추천함. 문제가 생기면 subdivisions 은 32까지 올릴 수 있다.
#
# 몇개의 class에 대하여 학습하는지에 따라 변경사항이 달라짐.
#
# 여기서는  **max_batches = 10000**, **steps = 8000, 9000**, I  **classes = 5** 로 놓았고, 각 YOLO 레이어전의 3개의 컨볼루셔널 레이어에서는 **filters = 30** 로 놓았다. (주의 : 이런 classes가 cfg파일안에 3개가 있다)
#
# **옵션:** 학습을 빠르게 하려면 cfg파일안의 yolo레이어에서 random = 1 에서 **random = 0** 으로 바꿀 수 있음. 대신 정확도는 약간 떨어지게 됨. 이렇게 함으로써 메모리 부족현상도 어느 정도 완화될 수 있다.
#
# save to drive버튼을 눌러서 save함.

# %%
# 커스텀 .cfg 파일을 다시 클라우드로 올림
# !cp /mydrive/yolov3/yolov3_custom.cfg ./cfg

# 다음과 같이 하면 PC에서 커스텀 .cfg 파일을 클라우드로 올릴 수 있음.
#%cd cfg
#upload()
#%cd ..

# %% [markdown]
# ## ii) obj.names 와 obj.data
# **obj.names** 라는 파일명을 만들고 classes.txt에 넣었던 것과 같은 내용을 입력함.
#
# ![image.png](data:image/png;base64,...)
#
#  **obj.data** 파일을 만들고 밑에와 같이 내용을 채움. 클래스의 갯수에 맞게 적고 backup 폴더의 위치를 지정하면 됨.
#
# backup 폴더는 학습이 진행될 때 weights값들이 저장이 되는 위치임. 먼저 구글 드라이브에 backup폴더를 만든 후에 이 폴더로 위치를 지정하면 됨.
#
# ![image.png](data:image/png;base64,...)

# %%
# obj.names 와 obj.data 파일들을 구글 드라이브에서 클라우드로 올리기
# !cp /mydrive/yolov3/obj.names ./data
# !cp /mydrive/yolov3/obj.data  ./data

# obj.names 와 obj.data 파일들을 PC에서 클라우드로 올리기
#%cd data
#upload()
#%cd ..

# %%
ls
# Out:
# 3rdparty/       darknet*                Dockerfile.cpu          Makefile        scripts/
# backup/         DarknetConfig.cmake.in  Dockerfile.gpu          net_cam_v3.sh*  src/
# build/          darknet_images.py       image_yolov3.sh*        net_cam_v4.sh*  vcpkg.json
# build.ps1*      darknet.py              image_yolov4.sh*        obj/            vcpkg.json.opencv23
# cfg/            darknet_video.py        include/                package.xml     video_yolov3.sh*
# cmake/          data/                   json_mjpeg_streams.sh*  README.md       video_yolov4.sh*
# CMakeLists.txt  docker-compose.yml      LICENSE                 results/

# %% [markdown]
# ## iii) train.txt 만들기
# 마지막으로 만들어야 하는 파일은 train.txt파일로, 이 파일은 학습에 사용하는 이미지들에 대한 상대경로를 가지고 있는 파일이다.
#
# train.txt 파일을 생성해주는 python script를 여기서 얻을 수 있다:[Github Repo](https://github.com/theAIGuysCode/YoloGenerateTrainingFile/blob/master/generate_train.py/)
#
# 이 파일을 PC나 구글드라이브에 다운로드한 후에 클라우드로 올리면 된다.

# %%
# 구글드라이브의 generate_train.py 스크립트를 클라우드로 올리기
# !cp /mydrive/yolov3/generate_train.py ./

# PC에서 generate_train.py 스크립트를 클라우드로 올리기
#upload()

# %% [markdown]
# 다음과 같이 python 스크립트를 실행하면 train.txt파일을 생성해준다.

# %%
# !python generate_train.py

# %%
# darknet/data폴더내에 train.txt이 존재함을 확인해보기
# !ls data/
# Out:
# 9k.tree     eagle.jpg	 imagenet.labels.list	   obj.data	     scream.jpg
# coco9k.map  giraffe.jpg  imagenet.shortnames.list  obj.names	     train.txt
# coco.names  goal.txt	 labels			   openimages.names  voc.names
# dog.jpg     horses.jpg	 obj			   person.jpg

# %% [markdown]
#  **train.txt** 을 더블클릭하여 에디터로 내부를 확인해보면 다음과 같이 보여질 것이다.
#
# ![image.png](data:image/png;base64,...)
#
# 라인마다 학습 이미지 경로가 존재함을 확인할 수 있다.

# %% [markdown]
# # Step 4: 사전학습된 weights 들을 다운로드하기
#
# 이 step은 YOLOv3 네트워크의 컨볼루션 레이어에 대한 weights들을 다운로드하는 step이다. 사전학습된 weights 들을 이용하면 학습시간을 줄일 수 있고, 정확도도 높일 수 있다.

# %%
# 사전학습된 convolutional layer weights를 다운로드하
# !wget http://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2024-05-28 05:57:54--  http://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 162.0.215.52
# Connecting to pjreddie.com (pjreddie.com)|162.0.215.52|:80... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: https://pjreddie.com/media/files/darknet53.conv.74 [following]
# --2024-05-28 05:57:54--  https://pjreddie.com/media/files/darknet53.conv.74
# Connecting to pjreddie.com (pjreddie.com)|162.0.215.52|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M  48.4MB/s    in 3.2s
#
# 2024-05-28 05:57:57 (48.4 MB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %% [markdown]
# # Step 5: 커스텀 Object Detector를 학습시키기
#
# 다음의 명령문으로 커스텀 Object Detector를 학습시킬 수 있다. 여기서 -dont_show 플래그는 chart를 보이지 않게 하는 플래그이다.
# ```
# !./darknet detector train <path to obj.data> <path to custom config> darknet53.conv.74 -dont_show
# ```
# **TIP:** 이 학습은 상당히 오래 걸리는데 구글 colab은 학습하다가 반응이 없으면 중간에 멈춘다. 이것을 방지 하기 위해 CTRL + SHIFT + i를 누른 후에 브라우저에 나타나는 console window에 다음의 코드를 복사하고 엔터키를 누른다.
#
# ```
# function ClickConnect(){
# console.log("Working");
# document.querySelector("colab-toolbar-button#connect").click()
# }
# setInterval(ClickConnect,60000)
# ```
#
# 위의 코드는 1분마다 스크린을 자동으로 클릭하여 colab이 멈추는 것을 방지하게 해준다.
#
# ![image.png](data:image/png;base64,...)

# %%
# 커스텀 detector를 학습시키기. 기존에 학습하다 말았으면 backup에 있는 weight를 불러서 학습하는 셀로 이동하기
# !./darknet detector train data/obj.data cfg/yolov3_custom.cfg darknet53.conv.74 -dont_show
# Out:
# ./darknet: error while loading shared libraries: libcuda.so.1: cannot open shared object file: No such file or directory

# %% [markdown]
# 밑의 명령문을 돌리면 모델이 학습을 진행하는 동안 iteration에 따른 평균 loss값이 어떻게 변했는지를 확인할 수 있다.

# %%
imShow('chart.png')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-096d9cb64b19> in <cell line: 1>()
# ----> 1 imShow('chart.png')
#
# <ipython-input-5-366da68b0fce> in imShow(path)
#       6
#       7   image = cv2.imread(path)  #경로로부터 이미지를 불러읽어들여서
# ----> 8   height, width = image.shape[:2]   #현재 영상의 height와 width를 읽어서
#       9   resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC) #영상을 3배로 키운다(크게 보여주기 위해서)
#      10
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %% [markdown]
# Colab이 어떤 이유에서 더 이상 학습을 진행하지 않는다고 해도 100 iteration마다 **yolov3_custom_last.weights** 이라는 weight파일이 **mydrive/yolov3/backup/** 폴더에 저장이 된다.
# 다음 명령문을 통해 마지막으로 저장한 weights파일을 다시 불러읽을 수 있다.
# ```
# !./darknet detector train data/obj.data cfg/yolov3_custom.cfg /mydrive/yolov3/backup/yolov3_custom_last.weights -dont_show
# ```

# %%
# !./darknet detector train data/obj.data cfg/yolov3_custom.cfg /mydrive/yolov3/backup/yolov3_custom_last.weights -dont_show
# Out:
#  CUDA-version: 12020 (12020), cuDNN: 8.9.6, GPU count: 1
#  OpenCV version: 4.5.4
# yolov3_custom
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 1
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    7 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#    8 Shortcut Layer: 5,  wt = 0, wn = 0, outputs: 104 x 104 x 128 0.001 BF
#    9 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#   10 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#   11 Shortcut Layer: 8,  wt = 0, wn = 0, outputs: 104 x 104 x 128 0.001 BF
#   12 conv    256       3 x 3/ 2    104 x 104 x 128 ->   52 x  52 x 256 1.595 BF
#   13 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   14 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   15 Shortcut Layer: 12,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   16 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   17 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   18 Shortcut Layer: 15,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   19 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   20 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   21 Shortcut Layer: 18,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   22 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   23 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   24 Shortcut Layer: 21,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   25 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   26 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   27 Shortcut Layer: 24,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   28 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   29 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   30 Shortcut Layer: 27,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   31 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   32 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   33 Shortcut Layer: 30,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   34 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   35 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   36 Shortcut Layer: 33,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   37 conv    512       3 x 3/ 2     52 x  52 x 256 ->   26 x  26 x 512 1.595 BF
#   38 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   39 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   40 Shortcut Layer: 37,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   41 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   42 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   43 Shortcut Layer: 40,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   44 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   45 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   46 Shortcut Layer: 43,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   47 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   48 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   49 Shortcut Layer: 46,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   50 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   51 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   52 Shortcut Layer: 49,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   53 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   54 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   55 Shortcut Layer: 52,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   56 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   57 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   58 Shortcut Layer: 55,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   59 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   60 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   61 Shortcut Layer: 58,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   62 conv   1024       3 x 3/ 2     26 x  26 x 512 ->   13 x  13 x1024 1.595 BF
#   63 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   64 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   65 Shortcut Layer: 62,  wt = 0, wn = 0, outputs:  13 x  13 x1024 0.000 BF
#   66 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   67 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   68 Shortcut Layer: 65,  wt = 0, wn = 0, outputs:  13 x  13 x1024 0.000 BF
#   69 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   70 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   71 Shortcut Layer: 68,  wt = 0, wn = 0, outputs:  13 x  13 x1024 0.000 BF
#   72 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   73 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   74 Shortcut Layer: 71,  wt = 0, wn = 0, outputs:  13 x  13 x1024 0.000 BF
#   75 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   76 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   77 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   78 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   79 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   80 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   81 conv     21       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x  21 0.007 BF
#   82 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
#   83 route  79 		                           ->   13 x  13 x 512
#   84 conv    256       1 x 1/ 1     13 x  13 x 512 ->   13 x  13 x 256 0.044 BF
#   85 upsample                 2x    13 x  13 x 256 ->   26 x  26 x 256
#   86 route  85 61 	                           ->   26 x  26 x 768
#   87 conv    256       1 x 1/ 1     26 x  26 x 768 ->   26 x  26 x 256 0.266 BF
#   88 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   89 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   90 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   91 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   92 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   93 conv     21       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x  21 0.015 BF
#   94 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
#   95 route  91 		                           ->   26 x  26 x 256
#   96 conv    128       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x 128 0.044 BF
#   97 upsample                 2x    26 x  26 x 128 ->   52 x  52 x 128
#   98 route  97 36 	                           ->   52 x  52 x 384
#   99 conv    128       1 x 1/ 1     52 x  52 x 384 ->   52 x  52 x 128 0.266 BF
#  100 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#  101 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#  102 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#  103 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#  104 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#  105 conv     21       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x  21 0.029 BF
#  106 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
# Total BFLOPS 65.312
# avg_outputs = 516922
#  Allocate additional workspace_size = 52.44 MB
# Loading weights from /mydrive/yolov3/backup/yolov3_custom_last.weights...
#  seen 64, trained: 160 K-images (2 Kilo-batches_64)
# Done! Loaded 107 layers from weights-file
# Darknet error location: ./src/detector.c, train_detector(), line #91
# Error: You set incorrect value batch=1 for Training! You should set batch=64 subdivision=64: Success
# backtrace (8 entries)
# 1/8: ./darknet(log_backtrace+0x38) [0x5d30f38a21f8]
# 2/8: ./darknet(error+0x3d) [0x5d30f38a22dd]
# 3/8: ./darknet(train_detector+0x36ac) [0x5d30f3930b5c]
# 4/8: ./darknet(run_detector+0xa32) [0x5d30f3932b62]
# 5/8: ./darknet(main+0x326) [0x5d30f3861766]
# 6/8: /lib/x86_64-linux-gnu/libc.so.6(+0x29d90) [0x7e195add4d90]
# 7/8: /lib/x86_64-linux-gnu/libc.so.6(__libc_start_main+0x80) [0x7e195add4e40]
# 8/8: ./darknet(_start+0x25) [0x5d30f38639e5]

# %% [markdown]
# # Step 6: 커스텀 Object Detector 실행하기
#
# 커스텀 Object Detector가 만들어졌기 때문에 이제 실행을 하면 됨.

# %%
# custom cfg 를 test mode 로 바꾸기
# %cd cfg
# !sed -i 's/batch=64/batch=1/' yolov3_custom.cfg
# !sed -i 's/subdivisions=16/subdivisions=1/' yolov3_custom.cfg
# %cd ..
# Out:
# /content/darknet/cfg
# /content/darknet

# %%
# 구글 드라이브로 원하는 영상을 업로드한 후에 커스텀 detector를 돌리기. 여기서 -thresh 0.3은 Accuracy가 0.3이하가 되는 Object의 Bounding Box는 보이지 않게 하겠다는 뜻임
# !./darknet detector test data/obj.data cfg/yolov3_custom.cfg /mydrive/yolov3/backup/yolov3_custom_last.weights /mydrive/images/gun.jpg -thresh 0.3
imShow('predictions.jpg')
# Out:
#  CUDA-version: 12020 (12020), cuDNN: 8.9.6, GPU count: 1
#  OpenCV version: 4.5.4
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    7 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#    8 Shortcut Layer: 5,  wt = 0, wn = 0, outputs: 104 x 104 x 128 0.001 BF
#    9 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#   10 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#   11 Shortcut Layer: 8,  wt = 0, wn = 0, outputs: 104 x 104 x 128 0.001 BF
#   12 conv    256       3 x 3/ 2    104 x 104 x 128 ->   52 x  52 x 256 1.595 BF
#   13 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   14 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   15 Shortcut Layer: 12,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   16 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   17 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   18 Shortcut Layer: 15,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   19 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   20 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   21 Shortcut Layer: 18,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   22 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   23 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   24 Shortcut Layer: 21,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   25 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   26 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   27 Shortcut Layer: 24,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   28 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   29 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   30 Shortcut Layer: 27,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   31 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   32 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   33 Shortcut Layer: 30,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   34 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   35 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#   36 Shortcut Layer: 33,  wt = 0, wn = 0, outputs:  52 x  52 x 256 0.001 BF
#   37 conv    512       3 x 3/ 2     52 x  52 x 256 ->   26 x  26 x 512 1.595 BF
#   38 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   39 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   40 Shortcut Layer: 37,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   41 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   42 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   43 Shortcut Layer: 40,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   44 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   45 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   46 Shortcut Layer: 43,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   47 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   48 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   49 Shortcut Layer: 46,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   50 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   51 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   52 Shortcut Layer: 49,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   53 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   54 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   55 Shortcut Layer: 52,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   56 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   57 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   58 Shortcut Layer: 55,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   59 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   60 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   61 Shortcut Layer: 58,  wt = 0, wn = 0, outputs:  26 x  26 x 512 0.000 BF
#   62 conv   1024       3 x 3/ 2     26 x  26 x 512 ->   13 x  13 x1024 1.595 BF
#   63 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   64 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   65 Shortcut Layer: 62,  wt = 0, wn = 0, outputs:  13 x  13 x1024 0.000 BF
#   66 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   67 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   68 Shortcut Layer: 65,  wt = 0, wn = 0, outputs:  13 x  13 x1024 0.000 BF
#   69 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   70 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   71 Shortcut Layer: 68,  wt = 0, wn = 0, outputs:  13 x  13 x1024 0.000 BF
#   72 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   73 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   74 Shortcut Layer: 71,  wt = 0, wn = 0, outputs:  13 x  13 x1024 0.000 BF
#   75 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   76 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   77 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   78 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   79 conv    512       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x 512 0.177 BF
#   80 conv   1024       3 x 3/ 1     13 x  13 x 512 ->   13 x  13 x1024 1.595 BF
#   81 conv     21       1 x 1/ 1     13 x  13 x1024 ->   13 x  13 x  21 0.007 BF
#   82 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
#   83 route  79 		                           ->   13 x  13 x 512
#   84 conv    256       1 x 1/ 1     13 x  13 x 512 ->   13 x  13 x 256 0.044 BF
#   85 upsample                 2x    13 x  13 x 256 ->   26 x  26 x 256
#   86 route  85 61 	                           ->   26 x  26 x 768
#   87 conv    256       1 x 1/ 1     26 x  26 x 768 ->   26 x  26 x 256 0.266 BF
#   88 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   89 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   90 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   91 conv    256       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x 256 0.177 BF
#   92 conv    512       3 x 3/ 1     26 x  26 x 256 ->   26 x  26 x 512 1.595 BF
#   93 conv     21       1 x 1/ 1     26 x  26 x 512 ->   26 x  26 x  21 0.015 BF
#   94 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
#   95 route  91 		                           ->   26 x  26 x 256
#   96 conv    128       1 x 1/ 1     26 x  26 x 256 ->   26 x  26 x 128 0.044 BF
#   97 upsample                 2x    26 x  26 x 128 ->   52 x  52 x 128
#   98 route  97 36 	                           ->   52 x  52 x 384
#   99 conv    128       1 x 1/ 1     52 x  52 x 384 ->   52 x  52 x 128 0.266 BF
#  100 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#  101 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#  102 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#  103 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#  104 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#  105 conv     21       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x  21 0.029 BF
#  106 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
# Total BFLOPS 65.312
# avg_outputs = 516922
#  Allocate additional workspace_size = 52.44 MB
# Loading weights from /mydrive/yolov3/backup/yolov3_custom_last.weights...
#  seen 64, trained: 160 K-images (2 Kilo-batches_64)
# Done! Loaded 107 layers from weights-file
# Cannot load image /mydrive/images/gun.jpg
#  Detection layer: 82 - type = 28
#  Detection layer: 94 - type = 28
#  Detection layer: 106 - type = 28
# /mydrive/images/gun.jpg: Predicted in 141.824000 milli-seconds.
# Drink: 82%
# OpenCV exception: show_image_cv

# %%
imShow('predictions.jpg')

# %% [markdown]
# 이 코드를 만든 AI Guy의 유튜브 링크:
#
# [The AI Guy](https://www.youtube.com/channel/UCrydcKaojc44XnuXrfhlV8Q)
